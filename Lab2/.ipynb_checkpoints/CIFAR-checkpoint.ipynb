# %%
import os
import pickle
import numpy as np
import tensorflow as tf
import math
import skimage as ski
import skimage.io
import matplotlib.pyplot as plt
import time
from copy import deepcopy
from confusion_matrix import get_confusion_matrix
from confusion_matrix import eval_AP
from confusion_matrix import eval_perf_multi

# %%
# Parameters
learning_policy = {1:1e-2, 3:1e-3, 5:1e-4, 7:1e-5, 9:1e-6}
training_iters = 200000
batch_size = 100
max_epochs = 60
print_every_num_batches = 20
draw_filter = 100
wd = 0

starter_learning_rate = 0.01
hinge_delta =10.
# Network Parameters
n_channel = 3
input_shape = [None, 32, 32, 3]
n_classes = 10

# tf Graph input

# %%
def shuffle_data(data_x, data_y):
    indices = np.arange(data_x.shape[0])
    np.random.shuffle(indices)
    shuffled_data_x = np.ascontiguousarray(data_x[indices])
    shuffled_data_y = np.ascontiguousarray(data_y[indices])
    return shuffled_data_x, shuffled_data_y

def unpickle(file):
    fo = open(file, 'rb')
    dict_ = pickle.load(fo)
    fo.close()
    return dict_

DATA_DIR = './CIFAR'
SAVE_DIR = './tensorflow_cifar'

img_height =32
img_width =32
num_channels=3

train_x = np.ndarray((0, img_height * img_width * num_channels), dtype=np.float32)
train_y = []
for i in range(1, 6):
    subset = unpickle(os.path.join(DATA_DIR, 'data_batch_%d' % i))
    train_x = np.vstack((train_x, subset['data']))
    train_y += subset['labels']
train_x = train_x.reshape((-1, num_channels, img_height, img_width)).transpose(0,2,3,1)
train_y = np.array(train_y, dtype=np.int32)

subset = unpickle(os.path.join(DATA_DIR, 'test_batch'))
test_x = subset['data'].reshape((-1, num_channels, img_height, img_width)).transpose(0,2,3,1).astype(np.float32)
test_y = np.array(subset['labels'], dtype=np.int32)

valid_size = 5000
train_x, train_y = shuffle_data(train_x, train_y)
valid_x = train_x[:valid_size, ...]
valid_y = train_y[:valid_size, ...]
train_x = train_x[valid_size:, ...]
train_y = train_y[valid_size:, ...]
data_mean = train_x.mean((0,1,2))
data_std = train_x.std((0,1,2))

train_x = (1.*train_x - data_mean) / data_std
valid_x = (1.*valid_x - data_mean) / data_std
test_x = (1.*test_x - data_mean) / data_std

# %%
import matplotlib.pyplot as plt
print train_x.shape
draw_image(test_x[3],data_mean,data_std)
# Out:
# (45000, 32, 32, 3)

# %%
def draw_conv_filters(epoch, step, weights, save_dir):
    w = weights.copy()
    num_filters = w.shape[3]
    num_channels = w.shape[2]
    k = w.shape[0]
    assert w.shape[0] == w.shape[1]
    w = w.reshape(k, k, num_channels, num_filters)
    w -= w.min()
    w /= w.max()
    border = 1
    cols = 8
    rows = math.ceil(num_filters / cols)
    width = cols * k + (cols-1) * border
    height = rows * k + (rows-1) * border
    img = np.zeros([height, width, num_channels])
    for i in range(num_filters):
        r = int(i / cols) * (k + border)
        c = int(i % cols) * (k + border)
        img[r:r+k,c:c+k,:] = w[:,:,:,i]
    filename = 'epoch_%02d_step_%06d.png' % (epoch, step)
    ski.io.imsave(os.path.join(save_dir, filename), img)

# %%
def draw_image(img, mean, std):
    img = img.copy()
    img *= std
    img += mean
    img = img.astype(np.uint8)
    ski.io.imshow(img)
    ski.io.show()

# %%
def plot_training_progress(save_dir, data):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,8))

    linewidth = 2
    legend_size = 10
    train_color = 'm'
    val_color = 'c'

    num_points = len(data['train_loss'])
    x_data = np.linspace(1, num_points, num_points)
    ax1.set_title('Cross-entropy loss')
    ax1.plot(x_data, data['train_loss'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
    ax1.plot(x_data, data['valid_loss'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
    ax1.legend(loc='upper right', fontsize=legend_size)
    ax2.set_title('Average class accuracy')
    ax2.plot(x_data, data['train_acc'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
    ax2.plot(x_data, data['valid_acc'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
    ax2.legend(loc='upper left', fontsize=legend_size)
    ax3.set_title('Learning rate')
    ax3.plot(x_data, data['lr'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='learning_rate')
    ax3.legend(loc='upper left', fontsize=legend_size)

    save_path = os.path.join(save_dir, 'training_plot.pdf')
    print('Plotting in: ', save_path)
    plt.savefig(save_path)

# %%
def evaluate(pred, cost, data_x, data_y):
    possible_labels = np.array(range(n_classes))
    for i in range(10,1,-1):
        if data_x.shape[0]%i==0:
            max_i = i
    
    predictions = None
    loss = 0
    for i in range(data_x.shape[0]/max_i):
        preds = sess.run(pred, feed_dict={ x: data_x[i*max_i:(i+1)*max_i]})
        loss += sess.run(cost, feed_dict={x: data_x[i*max_i:(i+1)*max_i], y: data_y[i*max_i:(i+1)*max_i]})*max_i
        if predictions == None:
            predictions = preds
        else:
            predictions = np.vstack((predictions,preds))
    loss/= data_x.shape[0]
    #print predictions.shape, max_i, i, data_y.shape
    mat = get_confusion_matrix(np.argmax(predictions,axis=1),np.argmax(data_y,axis=1),possible_labels,False)
    accuracy, prec, rec = eval_perf_multi(mat)
    #print accuracy
    #print '\n'.join(map(str,list(zip(map(lambda x: "Class: "+str(x),range(0,10)), \
    #                             map(lambda x: "Recall: "+str(x),rec), \
    #                             map(lambda x: "Precision: "+str(x),prec)))))
    return  loss, accuracy

# %%
# Store layers weight & bias
# weights = {
#     'wc1': tf.Variable(tf.random_normal([5, 5, n_channel, 16])),
#     'wc2': tf.Variable(tf.random_normal([5, 5, 16, 32])),
#     'wd1': tf.Variable(tf.random_normal([8*8*32, 256])),
#     'wd2': tf.Variable(tf.random_normal([256, 128])),
#     'out': tf.Variable(tf.random_normal([128, n_classes]))
# }
# biases = {
#     'bc1': tf.Variable(tf.random_normal([16])),
#     'bc2': tf.Variable(tf.random_normal([32])),
#     'bd1': tf.Variable(tf.random_normal([256])),
#     'bd2': tf.Variable(tf.random_normal([128])),
#     'out': tf.Variable(tf.random_normal([n_classes]))
# }

tf.reset_default_graph()
weights = {
    'wc1': tf.get_variable('wc1',[5, 5, n_channel, 16],initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wc2': tf.get_variable('wc2',[5, 5, 16, 32],initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wd1': tf.get_variable('wd1',[8*8*32, 256],initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'wd2': tf.get_variable('wd2',[256, 128],initializer=tf.contrib.layers.xavier_initializer_conv2d()),
    'out': tf.get_variable('out',[128, n_classes],initializer=tf.contrib.layers.xavier_initializer_conv2d())
}
biases = {
    'bc1': tf.Variable(tf.random_normal([16])),
    'bc2': tf.Variable(tf.random_normal([32])),
    'bd1': tf.Variable(tf.random_normal([256])),
    'bd2': tf.Variable(tf.random_normal([128])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

x = tf.placeholder(tf.float32, input_shape)
y = tf.placeholder(tf.float32, [None, n_classes])

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2, stride=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, stride, stride, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases):#,dropout):
    # Reshape input picture
    #x = tf.reshape(x, shape=[-1, 32, 32, 3])
    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=3, stride =2)
    
    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=3, stride=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    #fc1 = tf.nn.dropout(fc1, dropout)
    fc2 = tf.add(tf.matmul(fc1, weights['wd2']), biases['bd2'])
    fc2 = tf.nn.relu(fc2)

    # Output, class prediction
    out = tf.add(tf.matmul(fc2, weights['out']), biases['out'])
    return out

# %%
# Construct model
pred = conv_net(x, weights, biases)

# Define loss and optimizer
def softmax_loss(pred, y):
    return (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))) 
#                       + tf.mul(tf.nn.l2_loss(weights['wc1']), wd)
#                       + tf.mul(tf.nn.l2_loss(weights['wc2']), wd)
#                       + tf.mul(tf.nn.l2_loss(weights['wd1']), wd)
#                       + tf.mul(tf.nn.l2_loss(weights['wd2']), wd)))

def multiclass_hinge_loss(scores,one_hot, delta):
    delta = tf.constant(delta)
    all_indices = tf.Variable([1.]*n_classes,trainable =False)
    svi_netocni_scoreovi = tf.mul(tf.add(scores,delta),tf.sub(all_indices,one_hot))
    svi_tocni_scoreovi = tf.mul(scores,one_hot)
    svi_tocni_scoreovi_reduced = tf.reduce_sum(svi_tocni_scoreovi,reduction_indices=1)
    svi_tocni_scoreovi_reduced_reshaped = tf.reshape(svi_tocni_scoreovi_reduced,[-1,1])
    maximum_razlike = tf.maximum(0., tf.sub(svi_netocni_scoreovi,svi_tocni_scoreovi_reduced_reshaped))
    multiclass_hinge = tf.reduce_sum(maximum_razlike,reduction_indices=1)
#     summed = tf.reduce_sum(multiclass_hinge)
    cost = tf.reduce_mean(multiclass_hinge)
    return cost

cost = multiclass_hinge_loss(pred,y, hinge_delta)


#ako ocu ja setat odkomentiram ovo
# learning_rate = tf.placeholder(tf.float32, shape=[])

decay_batch = 10
decay_rate = 0.91
starter_learning_rate = 0.005
global_step = tf.Variable(0,trainable=False)

learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, decay_batch * batch_size, decay_rate)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost, global_step)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
def labels_to_one_hot(Y,C):
    Yoh_ = np.zeros((Y.shape[0],C))
    Yoh_[range(Y.shape[0]),Y] = 1
    return Yoh_

# %% [markdown]
# # Softmax

# %%
with tf.device('/gpu:0'):
    sess = tf.Session()
    sess.run(init)
    plot_data = {}
    plot_data['train_loss'] = []
    plot_data['valid_loss'] = []
    plot_data['train_acc'] = []
    plot_data['valid_acc'] = []
    plot_data['lr'] = []

    num_examples = train_x.shape[0]
    num_batches = num_examples/batch_size
    #logits = pred
    #loss = cost
    #train_op = optimizer

    for epoch_num in range(1, max_epochs + 1):
        train_x, train_y = shuffle_data(train_x, train_y)
        for step in range(num_batches):
            offset = step * batch_size 
            # s ovim kodom pazite da je broj primjera djeljiv s batch_size
            batch_x = train_x[offset:(offset + batch_size), ...]
            batch_y = train_y[offset:(offset + batch_size)]
            batch_y = labels_to_one_hot(np.array(batch_y),n_classes)
#             feed_dict = {x: batch_x, y: batch_y, learning_rate: 0.05}
            feed_dict = {x: batch_x, y: batch_y}
            start_time = time.time()
            run_ops = [optimizer, cost, pred]
            ret_val = sess.run(run_ops, feed_dict=feed_dict)
            _, loss_val, logits_val = ret_val
            duration = time.time() - start_time
            if (step+1) % 50 == 0:
                sec_per_batch = float(duration)
                format_str = 'epoch %d, step %d / %d, loss = %.2f (%.3f sec/batch)'
                print format_str % (epoch_num, step+1, num_batches, loss_val, sec_per_batch)

        train_loss, train_acc = evaluate(pred, cost, train_x, labels_to_one_hot(np.array(train_y),n_classes))
        print 'Train loss: %s , train acc: %s' %(train_loss, train_acc)

        valid_loss, valid_acc = evaluate(pred, cost, valid_x, labels_to_one_hot(np.array(valid_y),n_classes))
        print 'Validation loss: %s, validation acc: %s' %(valid_loss, valid_acc) 

        plot_data['train_loss'] += [train_loss]
        plot_data['valid_loss'] += [valid_loss]
        plot_data['train_acc'] += [train_acc]
        plot_data['valid_acc'] += [valid_acc]
        plot_data['lr'] += [learning_rate.eval(session=sess)]
        #plot_data['lr'] += [0]
        plot_training_progress(SAVE_DIR, plot_data)
# Out:
# epoch 1, step 50 / 450, loss = 1.93 (0.027 sec/batch)
# epoch 1, step 100 / 450, loss = 1.89 (0.027 sec/batch)
# epoch 1, step 150 / 450, loss = 1.94 (0.027 sec/batch)
# epoch 1, step 200 / 450, loss = 1.67 (0.028 sec/batch)
# epoch 1, step 250 / 450, loss = 1.78 (0.028 sec/batch)
# epoch 1, step 300 / 450, loss = 1.86 (0.027 sec/batch)
# epoch 1, step 350 / 450, loss = 1.73 (0.027 sec/batch)
# epoch 1, step 400 / 450, loss = 1.67 (0.027 sec/batch)
# epoch 1, step 450 / 450, loss = 1.55 (0.027 sec/batch)
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:12: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Train loss: 1.59489970937 , train acc: 0.409177777778
# Validation loss: 1.61849049722, validation acc: 0.4026
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 2, step 50 / 450, loss = 1.53 (0.028 sec/batch)
# epoch 2, step 100 / 450, loss = 1.82 (0.027 sec/batch)
# epoch 2, step 150 / 450, loss = 1.49 (0.028 sec/batch)
# epoch 2, step 200 / 450, loss = 1.49 (0.027 sec/batch)
# epoch 2, step 250 / 450, loss = 1.65 (0.027 sec/batch)
# epoch 2, step 300 / 450, loss = 1.58 (0.027 sec/batch)
# epoch 2, step 350 / 450, loss = 1.68 (0.028 sec/batch)
# epoch 2, step 400 / 450, loss = 1.50 (0.027 sec/batch)
# epoch 2, step 450 / 450, loss = 1.55 (0.028 sec/batch)
# Train loss: 1.52909849176 , train acc: 0.437444444444
# Validation loss: 1.57508760949, validation acc: 0.422
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 3, step 50 / 450, loss = 1.46 (0.027 sec/batch)
# epoch 3, step 100 / 450, loss = 1.46 (0.027 sec/batch)
# epoch 3, step 150 / 450, loss = 1.40 (0.027 sec/batch)
# epoch 3, step 200 / 450, loss = 1.62 (0.027 sec/batch)
# epoch 3, step 250 / 450, loss = 1.54 (0.027 sec/batch)
# epoch 3, step 300 / 450, loss = 1.48 (0.027 sec/batch)
# epoch 3, step 350 / 450, loss = 1.63 (0.027 sec/batch)
# epoch 3, step 400 / 450, loss = 1.54 (0.027 sec/batch)
# epoch 3, step 450 / 450, loss = 1.59 (0.027 sec/batch)
# Train loss: 1.43683381108 , train acc: 0.475955555556
# Validation loss: 1.51782908078, validation acc: 0.4476
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 4, step 50 / 450, loss = 1.34 (0.027 sec/batch)
# epoch 4, step 100 / 450, loss = 1.54 (0.027 sec/batch)
# epoch 4, step 150 / 450, loss = 1.55 (0.027 sec/batch)
# epoch 4, step 200 / 450, loss = 1.62 (0.027 sec/batch)
# epoch 4, step 250 / 450, loss = 1.35 (0.028 sec/batch)
# epoch 4, step 300 / 450, loss = 1.53 (0.027 sec/batch)
# epoch 4, step 350 / 450, loss = 1.29 (0.027 sec/batch)
# epoch 4, step 400 / 450, loss = 1.24 (0.027 sec/batch)
# epoch 4, step 450 / 450, loss = 1.65 (0.027 sec/batch)
# Train loss: 1.45370864698 , train acc: 0.465
# Validation loss: 1.5087657618, validation acc: 0.4498
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 5, step 50 / 450, loss = 1.29 (0.027 sec/batch)
# epoch 5, step 100 / 450, loss = 1.52 (0.027 sec/batch)
# epoch 5, step 150 / 450, loss = 1.35 (0.027 sec/batch)
# epoch 5, step 200 / 450, loss = 1.41 (0.027 sec/batch)
# epoch 5, step 250 / 450, loss = 1.47 (0.027 sec/batch)
# epoch 5, step 300 / 450, loss = 1.33 (0.027 sec/batch)
# epoch 5, step 350 / 450, loss = 1.45 (0.028 sec/batch)
# epoch 5, step 400 / 450, loss = 1.35 (0.027 sec/batch)
# epoch 5, step 450 / 450, loss = 1.53 (0.027 sec/batch)
# Train loss: 1.39639443822 , train acc: 0.500022222222
# Validation loss: 1.467653016, validation acc: 0.484
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 6, step 50 / 450, loss = 1.42 (0.027 sec/batch)
# epoch 6, step 100 / 450, loss = 1.40 (0.027 sec/batch)
# epoch 6, step 150 / 450, loss = 1.47 (0.028 sec/batch)
# epoch 6, step 200 / 450, loss = 1.47 (0.027 sec/batch)
# epoch 6, step 250 / 450, loss = 1.38 (0.028 sec/batch)
# epoch 6, step 300 / 450, loss = 1.33 (0.027 sec/batch)
# epoch 6, step 350 / 450, loss = 1.23 (0.027 sec/batch)
# epoch 6, step 400 / 450, loss = 1.44 (0.027 sec/batch)
# epoch 6, step 450 / 450, loss = 1.38 (0.027 sec/batch)
# Train loss: 1.35932929001 , train acc: 0.505422222222
# Validation loss: 1.43317605589, validation acc: 0.4852
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 7, step 50 / 450, loss = 1.61 (0.027 sec/batch)
# epoch 7, step 100 / 450, loss = 1.33 (0.027 sec/batch)
# epoch 7, step 150 / 450, loss = 1.39 (0.027 sec/batch)
# epoch 7, step 200 / 450, loss = 1.25 (0.027 sec/batch)
# epoch 7, step 250 / 450, loss = 1.30 (0.027 sec/batch)
# epoch 7, step 300 / 450, loss = 1.31 (0.027 sec/batch)
# epoch 7, step 350 / 450, loss = 1.28 (0.027 sec/batch)
# epoch 7, step 400 / 450, loss = 1.31 (0.027 sec/batch)
# epoch 7, step 450 / 450, loss = 1.29 (0.027 sec/batch)
# Train loss: 1.23681655663 , train acc: 0.559666666667
# Validation loss: 1.34754897515, validation acc: 0.5262
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 8, step 50 / 450, loss = 1.10 (0.028 sec/batch)
# epoch 8, step 100 / 450, loss = 1.29 (0.027 sec/batch)
# epoch 8, step 150 / 450, loss = 1.41 (0.027 sec/batch)
# epoch 8, step 200 / 450, loss = 1.26 (0.027 sec/batch)
# epoch 8, step 250 / 450, loss = 1.41 (0.027 sec/batch)
# epoch 8, step 300 / 450, loss = 1.42 (0.027 sec/batch)
# epoch 8, step 350 / 450, loss = 1.20 (0.027 sec/batch)
# epoch 8, step 400 / 450, loss = 1.20 (0.027 sec/batch)
# epoch 8, step 450 / 450, loss = 1.39 (0.027 sec/batch)
# Train loss: 1.23348849749 , train acc: 0.562222222222
# Validation loss: 1.33358669263, validation acc: 0.5312
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 9, step 50 / 450, loss = 1.36 (0.027 sec/batch)
# epoch 9, step 100 / 450, loss = 1.35 (0.027 sec/batch)
# epoch 9, step 150 / 450, loss = 1.17 (0.027 sec/batch)
# epoch 9, step 200 / 450, loss = 1.27 (0.027 sec/batch)
# epoch 9, step 250 / 450, loss = 1.28 (0.027 sec/batch)
# epoch 9, step 300 / 450, loss = 1.27 (0.027 sec/batch)
# epoch 9, step 350 / 450, loss = 1.15 (0.027 sec/batch)
# epoch 9, step 400 / 450, loss = 1.49 (0.027 sec/batch)
# epoch 9, step 450 / 450, loss = 1.16 (0.027 sec/batch)
# Train loss: 1.25140326467 , train acc: 0.562044444444
# Validation loss: 1.37823695869, validation acc: 0.5196
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 10, step 50 / 450, loss = 1.18 (0.027 sec/batch)
# epoch 10, step 100 / 450, loss = 1.21 (0.027 sec/batch)
# epoch 10, step 150 / 450, loss = 1.18 (0.027 sec/batch)
# epoch 10, step 200 / 450, loss = 1.28 (0.027 sec/batch)
# epoch 10, step 250 / 450, loss = 1.25 (0.027 sec/batch)
# epoch 10, step 300 / 450, loss = 1.35 (0.027 sec/batch)
# epoch 10, step 350 / 450, loss = 1.13 (0.027 sec/batch)
# epoch 10, step 400 / 450, loss = 1.15 (0.028 sec/batch)
# epoch 10, step 450 / 450, loss = 1.23 (0.027 sec/batch)
# Train loss: 1.17282955853 , train acc: 0.584577777778
# Validation loss: 1.31112352895, validation acc: 0.5512
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 11, step 50 / 450, loss = 1.10 (0.027 sec/batch)
# epoch 11, step 100 / 450, loss = 1.40 (0.027 sec/batch)
# epoch 11, step 150 / 450, loss = 1.28 (0.028 sec/batch)
# epoch 11, step 200 / 450, loss = 1.06 (0.027 sec/batch)
# epoch 11, step 250 / 450, loss = 1.24 (0.027 sec/batch)
# epoch 11, step 300 / 450, loss = 1.27 (0.027 sec/batch)
# epoch 11, step 350 / 450, loss = 1.18 (0.027 sec/batch)
# epoch 11, step 400 / 450, loss = 1.24 (0.027 sec/batch)
# epoch 11, step 450 / 450, loss = 1.08 (0.027 sec/batch)
# Train loss: 1.14815979025 , train acc: 0.585888888889
# Validation loss: 1.27346114448, validation acc: 0.5544
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 12, step 50 / 450, loss = 1.14 (0.027 sec/batch)
# epoch 12, step 100 / 450, loss = 1.18 (0.027 sec/batch)
# epoch 12, step 150 / 450, loss = 1.04 (0.027 sec/batch)
# epoch 12, step 200 / 450, loss = 1.31 (0.027 sec/batch)
# epoch 12, step 250 / 450, loss = 1.02 (0.027 sec/batch)
# epoch 12, step 300 / 450, loss = 1.12 (0.027 sec/batch)
# epoch 12, step 350 / 450, loss = 1.27 (0.027 sec/batch)
# epoch 12, step 400 / 450, loss = 1.28 (0.027 sec/batch)
# epoch 12, step 450 / 450, loss = 1.20 (0.027 sec/batch)
# Train loss: 1.11044035303 , train acc: 0.609311111111
# Validation loss: 1.25771822858, validation acc: 0.5618
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 13, step 50 / 450, loss = 0.92 (0.027 sec/batch)
# epoch 13, step 100 / 450, loss = 1.02 (0.027 sec/batch)
# epoch 13, step 150 / 450, loss = 1.02 (0.027 sec/batch)
# epoch 13, step 200 / 450, loss = 1.17 (0.027 sec/batch)
# epoch 13, step 250 / 450, loss = 1.18 (0.027 sec/batch)
# epoch 13, step 300 / 450, loss = 1.17 (0.027 sec/batch)
# epoch 13, step 350 / 450, loss = 0.90 (0.027 sec/batch)
# epoch 13, step 400 / 450, loss = 1.10 (0.027 sec/batch)
# epoch 13, step 450 / 450, loss = 1.09 (0.027 sec/batch)
# Train loss: 1.15316908935 , train acc: 0.590888888889
# Validation loss: 1.31689423613, validation acc: 0.542
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 14, step 50 / 450, loss = 0.96 (0.027 sec/batch)
# epoch 14, step 100 / 450, loss = 1.05 (0.027 sec/batch)
# epoch 14, step 150 / 450, loss = 1.14 (0.027 sec/batch)
# epoch 14, step 200 / 450, loss = 1.25 (0.027 sec/batch)
# epoch 14, step 250 / 450, loss = 1.34 (0.027 sec/batch)
# epoch 14, step 300 / 450, loss = 1.16 (0.027 sec/batch)
# epoch 14, step 350 / 450, loss = 1.03 (0.027 sec/batch)
# epoch 14, step 400 / 450, loss = 1.06 (0.027 sec/batch)
# epoch 14, step 450 / 450, loss = 1.09 (0.027 sec/batch)
# Train loss: 1.05288941209 , train acc: 0.628511111111
# Validation loss: 1.24791652225, validation acc: 0.577
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 15, step 50 / 450, loss = 1.05 (0.027 sec/batch)
# epoch 15, step 100 / 450, loss = 1.11 (0.027 sec/batch)
# epoch 15, step 150 / 450, loss = 1.10 (0.027 sec/batch)
# epoch 15, step 200 / 450, loss = 1.01 (0.028 sec/batch)
# epoch 15, step 250 / 450, loss = 1.00 (0.027 sec/batch)
# epoch 15, step 300 / 450, loss = 1.07 (0.027 sec/batch)
# epoch 15, step 350 / 450, loss = 0.99 (0.027 sec/batch)
# epoch 15, step 400 / 450, loss = 1.09 (0.027 sec/batch)
# epoch 15, step 450 / 450, loss = 0.90 (0.027 sec/batch)
# Train loss: 1.03421995241 , train acc: 0.632711111111
# Validation loss: 1.27525045371, validation acc: 0.5682
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 16, step 50 / 450, loss = 0.98 (0.027 sec/batch)
# epoch 16, step 100 / 450, loss = 0.86 (0.028 sec/batch)
# epoch 16, step 150 / 450, loss = 0.97 (0.028 sec/batch)
# epoch 16, step 200 / 450, loss = 1.21 (0.027 sec/batch)
# epoch 16, step 250 / 450, loss = 1.14 (0.027 sec/batch)
# epoch 16, step 300 / 450, loss = 1.57 (0.028 sec/batch)
# epoch 16, step 350 / 450, loss = 0.92 (0.027 sec/batch)
# epoch 16, step 400 / 450, loss = 0.97 (0.028 sec/batch)
# epoch 16, step 450 / 450, loss = 0.98 (0.027 sec/batch)
# Train loss: 0.997763196363 , train acc: 0.645666666667
# Validation loss: 1.22431144788, validation acc: 0.5896
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 17, step 50 / 450, loss = 0.92 (0.027 sec/batch)
# epoch 17, step 100 / 450, loss = 1.06 (0.027 sec/batch)
# epoch 17, step 150 / 450, loss = 1.13 (0.027 sec/batch)
# epoch 17, step 200 / 450, loss = 1.08 (0.027 sec/batch)
# epoch 17, step 250 / 450, loss = 0.93 (0.028 sec/batch)
# epoch 17, step 300 / 450, loss = 0.96 (0.027 sec/batch)
# epoch 17, step 350 / 450, loss = 1.12 (0.027 sec/batch)
# epoch 17, step 400 / 450, loss = 0.93 (0.027 sec/batch)
# epoch 17, step 450 / 450, loss = 0.91 (0.028 sec/batch)
# Train loss: 0.968826863315 , train acc: 0.6602
# Validation loss: 1.21651028942, validation acc: 0.5914
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 18, step 50 / 450, loss = 0.84 (0.027 sec/batch)
# epoch 18, step 100 / 450, loss = 0.92 (0.027 sec/batch)
# epoch 18, step 150 / 450, loss = 0.90 (0.027 sec/batch)
# epoch 18, step 200 / 450, loss = 1.05 (0.027 sec/batch)
# epoch 18, step 250 / 450, loss = 1.05 (0.027 sec/batch)
# epoch 18, step 300 / 450, loss = 0.96 (0.027 sec/batch)
# epoch 18, step 350 / 450, loss = 0.76 (0.027 sec/batch)
# epoch 18, step 400 / 450, loss = 0.86 (0.027 sec/batch)
# epoch 18, step 450 / 450, loss = 0.99 (0.027 sec/batch)
# Train loss: 0.959310468637 , train acc: 0.661644444444
# Validation loss: 1.22470956237, validation acc: 0.5922
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 19, step 50 / 450, loss = 1.02 (0.027 sec/batch)
# epoch 19, step 100 / 450, loss = 0.82 (0.027 sec/batch)
# epoch 19, step 150 / 450, loss = 1.00 (0.027 sec/batch)
# epoch 19, step 200 / 450, loss = 1.01 (0.027 sec/batch)
# epoch 19, step 250 / 450, loss = 0.88 (0.027 sec/batch)
# epoch 19, step 300 / 450, loss = 0.93 (0.027 sec/batch)
# epoch 19, step 350 / 450, loss = 0.71 (0.027 sec/batch)
# epoch 19, step 400 / 450, loss = 0.71 (0.027 sec/batch)
# epoch 19, step 450 / 450, loss = 0.92 (0.027 sec/batch)
# Train loss: 0.895666621229 , train acc: 0.683311111111
# Validation loss: 1.20985488675, validation acc: 0.595
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 20, step 50 / 450, loss = 0.89 (0.027 sec/batch)
# epoch 20, step 100 / 450, loss = 0.85 (0.027 sec/batch)
# epoch 20, step 150 / 450, loss = 0.81 (0.027 sec/batch)
# epoch 20, step 200 / 450, loss = 1.15 (0.027 sec/batch)
# epoch 20, step 250 / 450, loss = 1.07 (0.027 sec/batch)
# epoch 20, step 300 / 450, loss = 0.76 (0.027 sec/batch)
# epoch 20, step 350 / 450, loss = 1.17 (0.027 sec/batch)
# epoch 20, step 400 / 450, loss = 0.96 (0.027 sec/batch)
# epoch 20, step 450 / 450, loss = 1.09 (0.027 sec/batch)
# Train loss: 0.872549093223 , train acc: 0.691333333333
# Validation loss: 1.20456034039, validation acc: 0.5984
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 21, step 50 / 450, loss = 0.97 (0.027 sec/batch)
# epoch 21, step 100 / 450, loss = 0.96 (0.027 sec/batch)
# epoch 21, step 150 / 450, loss = 0.91 (0.028 sec/batch)
# epoch 21, step 200 / 450, loss = 0.81 (0.028 sec/batch)
# epoch 21, step 250 / 450, loss = 1.07 (0.027 sec/batch)
# epoch 21, step 300 / 450, loss = 0.88 (0.027 sec/batch)
# epoch 21, step 350 / 450, loss = 1.08 (0.027 sec/batch)
# epoch 21, step 400 / 450, loss = 0.79 (0.027 sec/batch)
# epoch 21, step 450 / 450, loss = 0.82 (0.027 sec/batch)
# Train loss: 0.825871005837 , train acc: 0.712533333333
# Validation loss: 1.17007718378, validation acc: 0.6062
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 22, step 50 / 450, loss = 0.68 (0.027 sec/batch)
# epoch 22, step 100 / 450, loss = 0.82 (0.028 sec/batch)
# epoch 22, step 150 / 450, loss = 1.08 (0.028 sec/batch)
# epoch 22, step 200 / 450, loss = 1.00 (0.027 sec/batch)
# epoch 22, step 250 / 450, loss = 0.76 (0.027 sec/batch)
# epoch 22, step 300 / 450, loss = 0.82 (0.027 sec/batch)
# epoch 22, step 350 / 450, loss = 0.78 (0.028 sec/batch)
# epoch 22, step 400 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 22, step 450 / 450, loss = 1.00 (0.027 sec/batch)
# Train loss: 0.816622657351 , train acc: 0.715288888889
# Validation loss: 1.21760159415, validation acc: 0.6124
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 23, step 50 / 450, loss = 0.83 (0.028 sec/batch)
# epoch 23, step 100 / 450, loss = 1.01 (0.027 sec/batch)
# epoch 23, step 150 / 450, loss = 0.58 (0.027 sec/batch)
# epoch 23, step 200 / 450, loss = 0.65 (0.027 sec/batch)
# epoch 23, step 250 / 450, loss = 0.74 (0.028 sec/batch)
# epoch 23, step 300 / 450, loss = 0.78 (0.027 sec/batch)
# epoch 23, step 350 / 450, loss = 0.77 (0.027 sec/batch)
# epoch 23, step 400 / 450, loss = 1.02 (0.027 sec/batch)
# epoch 23, step 450 / 450, loss = 0.90 (0.027 sec/batch)
# Train loss: 0.787371897968 , train acc: 0.729533333333
# Validation loss: 1.17677418003, validation acc: 0.6186
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 24, step 50 / 450, loss = 0.82 (0.027 sec/batch)
# epoch 24, step 100 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 24, step 150 / 450, loss = 0.66 (0.027 sec/batch)
# epoch 24, step 200 / 450, loss = 0.79 (0.027 sec/batch)
# epoch 24, step 250 / 450, loss = 0.89 (0.027 sec/batch)
# epoch 24, step 300 / 450, loss = 0.95 (0.027 sec/batch)
# epoch 24, step 350 / 450, loss = 0.81 (0.027 sec/batch)
# epoch 24, step 400 / 450, loss = 0.96 (0.028 sec/batch)
# epoch 24, step 450 / 450, loss = 0.73 (0.027 sec/batch)
# Train loss: 0.759115239317 , train acc: 0.736022222222
# Validation loss: 1.23002804002, validation acc: 0.6062
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 25, step 50 / 450, loss = 0.89 (0.027 sec/batch)
# epoch 25, step 100 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 25, step 150 / 450, loss = 0.86 (0.027 sec/batch)
# epoch 25, step 200 / 450, loss = 0.55 (0.028 sec/batch)
# epoch 25, step 250 / 450, loss = 1.00 (0.027 sec/batch)
# epoch 25, step 300 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 25, step 350 / 450, loss = 0.86 (0.027 sec/batch)
# epoch 25, step 400 / 450, loss = 0.92 (0.027 sec/batch)
# epoch 25, step 450 / 450, loss = 0.65 (0.027 sec/batch)
# Train loss: 0.712241518732 , train acc: 0.751311111111
# Validation loss: 1.19855199657, validation acc: 0.6116
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 26, step 50 / 450, loss = 0.83 (0.027 sec/batch)
# epoch 26, step 100 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 26, step 150 / 450, loss = 0.80 (0.027 sec/batch)
# epoch 26, step 200 / 450, loss = 0.66 (0.028 sec/batch)
# epoch 26, step 250 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 26, step 300 / 450, loss = 0.68 (0.027 sec/batch)
# epoch 26, step 350 / 450, loss = 0.88 (0.027 sec/batch)
# epoch 26, step 400 / 450, loss = 0.70 (0.027 sec/batch)
# epoch 26, step 450 / 450, loss = 0.78 (0.028 sec/batch)
# Train loss: 0.71233159904 , train acc: 0.752822222222
# Validation loss: 1.26362808627, validation acc: 0.6076
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 27, step 50 / 450, loss = 0.73 (0.027 sec/batch)
# epoch 27, step 100 / 450, loss = 0.53 (0.027 sec/batch)
# epoch 27, step 150 / 450, loss = 0.75 (0.027 sec/batch)
# epoch 27, step 200 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 27, step 250 / 450, loss = 0.70 (0.027 sec/batch)
# epoch 27, step 300 / 450, loss = 0.75 (0.027 sec/batch)
# epoch 27, step 350 / 450, loss = 0.67 (0.027 sec/batch)
# epoch 27, step 400 / 450, loss = 0.62 (0.028 sec/batch)
# epoch 27, step 450 / 450, loss = 0.60 (0.027 sec/batch)
# Train loss: 0.6585958226 , train acc: 0.770222222222
# Validation loss: 1.28797759536, validation acc: 0.619
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 28, step 50 / 450, loss = 0.68 (0.027 sec/batch)
# epoch 28, step 100 / 450, loss = 0.62 (0.027 sec/batch)
# epoch 28, step 150 / 450, loss = 0.68 (0.027 sec/batch)
# epoch 28, step 200 / 450, loss = 0.76 (0.027 sec/batch)
# epoch 28, step 250 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 28, step 300 / 450, loss = 0.77 (0.027 sec/batch)
# epoch 28, step 350 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 28, step 400 / 450, loss = 0.82 (0.027 sec/batch)
# epoch 28, step 450 / 450, loss = 0.80 (0.027 sec/batch)
# Train loss: 0.62986644321 , train acc: 0.780444444444
# Validation loss: 1.27212720061, validation acc: 0.6204
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 29, step 50 / 450, loss = 0.53 (0.027 sec/batch)
# epoch 29, step 100 / 450, loss = 0.60 (0.028 sec/batch)
# epoch 29, step 150 / 450, loss = 0.73 (0.027 sec/batch)
# epoch 29, step 200 / 450, loss = 0.55 (0.027 sec/batch)
# epoch 29, step 250 / 450, loss = 0.60 (0.027 sec/batch)
# epoch 29, step 300 / 450, loss = 0.62 (0.028 sec/batch)
# epoch 29, step 350 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 29, step 400 / 450, loss = 0.77 (0.027 sec/batch)
# epoch 29, step 450 / 450, loss = 0.80 (0.027 sec/batch)
# Train loss: 0.6420818137 , train acc: 0.7772
# Validation loss: 1.31659243349, validation acc: 0.6086
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 30, step 50 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 30, step 100 / 450, loss = 0.58 (0.027 sec/batch)
# epoch 30, step 150 / 450, loss = 0.48 (0.027 sec/batch)
# epoch 30, step 200 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 30, step 250 / 450, loss = 0.60 (0.027 sec/batch)
# epoch 30, step 300 / 450, loss = 0.90 (0.027 sec/batch)
# epoch 30, step 350 / 450, loss = 0.77 (0.027 sec/batch)
# epoch 30, step 400 / 450, loss = 0.43 (0.027 sec/batch)
# epoch 30, step 450 / 450, loss = 0.74 (0.027 sec/batch)
# Train loss: 0.59703554009 , train acc: 0.793844444444
# Validation loss: 1.27796239309, validation acc: 0.619
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 31, step 50 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 31, step 100 / 450, loss = 0.53 (0.028 sec/batch)
# epoch 31, step 150 / 450, loss = 0.62 (0.027 sec/batch)
# epoch 31, step 200 / 450, loss = 0.65 (0.027 sec/batch)
# epoch 31, step 250 / 450, loss = 0.57 (0.027 sec/batch)
# epoch 31, step 300 / 450, loss = 0.81 (0.028 sec/batch)
# epoch 31, step 350 / 450, loss = 0.45 (0.027 sec/batch)
# epoch 31, step 400 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 31, step 450 / 450, loss = 0.65 (0.027 sec/batch)
# Train loss: 0.600876839224 , train acc: 0.791711111111
# Validation loss: 1.36313221599, validation acc: 0.6102
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 32, step 50 / 450, loss = 0.51 (0.027 sec/batch)
# epoch 32, step 100 / 450, loss = 0.61 (0.027 sec/batch)
# epoch 32, step 150 / 450, loss = 0.56 (0.027 sec/batch)
# epoch 32, step 200 / 450, loss = 0.85 (0.027 sec/batch)
# epoch 32, step 250 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 32, step 300 / 450, loss = 0.56 (0.027 sec/batch)
# epoch 32, step 350 / 450, loss = 0.68 (0.027 sec/batch)
# epoch 32, step 400 / 450, loss = 0.60 (0.027 sec/batch)
# epoch 32, step 450 / 450, loss = 0.74 (0.027 sec/batch)
# Train loss: 0.554511145097 , train acc: 0.806733333333
# Validation loss: 1.41211894837, validation acc: 0.613
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 33, step 50 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 33, step 100 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 33, step 150 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 33, step 200 / 450, loss = 0.77 (0.027 sec/batch)
# epoch 33, step 250 / 450, loss = 0.56 (0.027 sec/batch)
# epoch 33, step 300 / 450, loss = 0.59 (0.027 sec/batch)
# epoch 33, step 350 / 450, loss = 0.70 (0.027 sec/batch)
# epoch 33, step 400 / 450, loss = 0.45 (0.027 sec/batch)
# epoch 33, step 450 / 450, loss = 0.65 (0.028 sec/batch)
# Train loss: 0.528117491374 , train acc: 0.816311111111
# Validation loss: 1.46552306333, validation acc: 0.6188
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 34, step 50 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 34, step 100 / 450, loss = 0.59 (0.027 sec/batch)
# epoch 34, step 150 / 450, loss = 0.51 (0.027 sec/batch)
# epoch 34, step 200 / 450, loss = 0.78 (0.027 sec/batch)
# epoch 34, step 250 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 34, step 300 / 450, loss = 0.61 (0.027 sec/batch)
# epoch 34, step 350 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 34, step 400 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 34, step 450 / 450, loss = 0.80 (0.027 sec/batch)
# Train loss: 0.524874461811 , train acc: 0.818266666667
# Validation loss: 1.49357701396, validation acc: 0.6166
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 35, step 50 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 35, step 100 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 35, step 150 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 35, step 200 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 35, step 250 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 35, step 300 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 35, step 350 / 450, loss = 0.65 (0.027 sec/batch)
# epoch 35, step 400 / 450, loss = 0.55 (0.027 sec/batch)
# epoch 35, step 450 / 450, loss = 0.54 (0.027 sec/batch)
# Train loss: 0.498924065546 , train acc: 0.828088888889
# Validation loss: 1.47065354189, validation acc: 0.617
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 36, step 50 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 36, step 100 / 450, loss = 0.57 (0.028 sec/batch)
# epoch 36, step 150 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 36, step 200 / 450, loss = 0.35 (0.027 sec/batch)
# epoch 36, step 250 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 36, step 300 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 36, step 350 / 450, loss = 0.67 (0.027 sec/batch)
# epoch 36, step 400 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 36, step 450 / 450, loss = 0.57 (0.027 sec/batch)
# Train loss: 0.478340593602 , train acc: 0.8342
# Validation loss: 1.52975312065, validation acc: 0.6154
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 37, step 50 / 450, loss = 0.59 (0.028 sec/batch)
# epoch 37, step 100 / 450, loss = 0.51 (0.027 sec/batch)
# epoch 37, step 150 / 450, loss = 0.51 (0.027 sec/batch)
# epoch 37, step 200 / 450, loss = 0.46 (0.027 sec/batch)
# epoch 37, step 250 / 450, loss = 0.48 (0.027 sec/batch)
# epoch 37, step 300 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 37, step 350 / 450, loss = 0.59 (0.027 sec/batch)
# epoch 37, step 400 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 37, step 450 / 450, loss = 0.63 (0.027 sec/batch)
# Train loss: 0.475139532327 , train acc: 0.835177777778
# Validation loss: 1.5938302276, validation acc: 0.6066
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 38, step 50 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 38, step 100 / 450, loss = 0.55 (0.027 sec/batch)
# epoch 38, step 150 / 450, loss = 0.57 (0.027 sec/batch)
# epoch 38, step 200 / 450, loss = 0.59 (0.027 sec/batch)
# epoch 38, step 250 / 450, loss = 0.56 (0.027 sec/batch)
# epoch 38, step 300 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 38, step 350 / 450, loss = 0.41 (0.027 sec/batch)
# epoch 38, step 400 / 450, loss = 0.56 (0.027 sec/batch)
# epoch 38, step 450 / 450, loss = 0.43 (0.027 sec/batch)
# Train loss: 0.449380948565 , train acc: 0.845044444444
# Validation loss: 1.67084296026, validation acc: 0.612
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 39, step 50 / 450, loss = 0.41 (0.027 sec/batch)
# epoch 39, step 100 / 450, loss = 0.34 (0.027 sec/batch)
# epoch 39, step 150 / 450, loss = 0.33 (0.028 sec/batch)
# epoch 39, step 200 / 450, loss = 0.53 (0.027 sec/batch)
# epoch 39, step 250 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 39, step 300 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 39, step 350 / 450, loss = 0.40 (0.028 sec/batch)
# epoch 39, step 400 / 450, loss = 0.35 (0.027 sec/batch)
# epoch 39, step 450 / 450, loss = 0.50 (0.027 sec/batch)
# Train loss: 0.425870665909 , train acc: 0.853622222222
# Validation loss: 1.72410999548, validation acc: 0.6106
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 40, step 50 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 40, step 100 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 40, step 150 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 40, step 200 / 450, loss = 0.42 (0.027 sec/batch)
# epoch 40, step 250 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 40, step 300 / 450, loss = 0.42 (0.027 sec/batch)
# epoch 40, step 350 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 40, step 400 / 450, loss = 0.50 (0.027 sec/batch)
# epoch 40, step 450 / 450, loss = 0.43 (0.027 sec/batch)
# Train loss: 0.401773326353 , train acc: 0.862955555556
# Validation loss: 1.72326420716, validation acc: 0.6166
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 41, step 50 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 41, step 100 / 450, loss = 0.64 (0.027 sec/batch)
# epoch 41, step 150 / 450, loss = 0.33 (0.027 sec/batch)
# epoch 41, step 200 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 41, step 250 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 41, step 300 / 450, loss = 0.48 (0.027 sec/batch)
# epoch 41, step 350 / 450, loss = 0.34 (0.027 sec/batch)
# epoch 41, step 400 / 450, loss = 0.46 (0.027 sec/batch)
# epoch 41, step 450 / 450, loss = 0.38 (0.027 sec/batch)
# Train loss: 0.398156156715 , train acc: 0.862911111111
# Validation loss: 1.7967748553, validation acc: 0.6118
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 42, step 50 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 42, step 100 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 42, step 150 / 450, loss = 0.41 (0.027 sec/batch)
# epoch 42, step 200 / 450, loss = 0.37 (0.027 sec/batch)
# epoch 42, step 250 / 450, loss = 0.34 (0.027 sec/batch)
# epoch 42, step 300 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 42, step 350 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 42, step 400 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 42, step 450 / 450, loss = 0.67 (0.027 sec/batch)
# Train loss: 0.392717920186 , train acc: 0.865444444444
# Validation loss: 1.82007757075, validation acc: 0.62
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 43, step 50 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 43, step 100 / 450, loss = 0.46 (0.027 sec/batch)
# epoch 43, step 150 / 450, loss = 0.48 (0.027 sec/batch)
# epoch 43, step 200 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 43, step 250 / 450, loss = 0.27 (0.027 sec/batch)
# epoch 43, step 300 / 450, loss = 0.27 (0.027 sec/batch)
# epoch 43, step 350 / 450, loss = 0.26 (0.028 sec/batch)
# epoch 43, step 400 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 43, step 450 / 450, loss = 0.39 (0.027 sec/batch)
# Train loss: 0.377740137711 , train acc: 0.870488888889
# Validation loss: 1.9500191518, validation acc: 0.61
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 44, step 50 / 450, loss = 0.41 (0.027 sec/batch)
# epoch 44, step 100 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 44, step 150 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 44, step 200 / 450, loss = 0.33 (0.027 sec/batch)
# epoch 44, step 250 / 450, loss = 0.33 (0.027 sec/batch)
# epoch 44, step 300 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 44, step 350 / 450, loss = 0.42 (0.027 sec/batch)
# epoch 44, step 400 / 450, loss = 0.57 (0.027 sec/batch)
# epoch 44, step 450 / 450, loss = 0.53 (0.027 sec/batch)
# Train loss: 0.378549864397 , train acc: 0.869133333333
# Validation loss: 2.01202067403, validation acc: 0.5974
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 45, step 50 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 45, step 100 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 45, step 150 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 45, step 200 / 450, loss = 0.35 (0.027 sec/batch)
# epoch 45, step 250 / 450, loss = 0.57 (0.027 sec/batch)
# epoch 45, step 300 / 450, loss = 0.36 (0.027 sec/batch)
# epoch 45, step 350 / 450, loss = 0.36 (0.027 sec/batch)
# epoch 45, step 400 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 45, step 450 / 450, loss = 0.34 (0.027 sec/batch)
# Train loss: 0.348055854611 , train acc: 0.881777777778
# Validation loss: 2.11568735561, validation acc: 0.6032
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 46, step 50 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 46, step 100 / 450, loss = 0.36 (0.027 sec/batch)
# epoch 46, step 150 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 46, step 200 / 450, loss = 0.45 (0.027 sec/batch)
# epoch 46, step 250 / 450, loss = 0.48 (0.027 sec/batch)
# epoch 46, step 300 / 450, loss = 0.27 (0.027 sec/batch)
# epoch 46, step 350 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 46, step 400 / 450, loss = 0.41 (0.027 sec/batch)
# epoch 46, step 450 / 450, loss = 0.48 (0.027 sec/batch)
# Train loss: 0.353683253894 , train acc: 0.879533333333
# Validation loss: 2.13923102768, validation acc: 0.605
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 47, step 50 / 450, loss = 0.43 (0.027 sec/batch)
# epoch 47, step 100 / 450, loss = 0.43 (0.027 sec/batch)
# epoch 47, step 150 / 450, loss = 0.31 (0.028 sec/batch)
# epoch 47, step 200 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 47, step 250 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 47, step 300 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 47, step 350 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 47, step 400 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 47, step 450 / 450, loss = 0.45 (0.027 sec/batch)
# Train loss: 0.326116152125 , train acc: 0.889577777778
# Validation loss: 2.19863630676, validation acc: 0.6108
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 48, step 50 / 450, loss = 0.18 (0.028 sec/batch)
# epoch 48, step 100 / 450, loss = 0.16 (0.027 sec/batch)
# epoch 48, step 150 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 48, step 200 / 450, loss = 0.37 (0.027 sec/batch)
# epoch 48, step 250 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 48, step 300 / 450, loss = 0.43 (0.027 sec/batch)
# epoch 48, step 350 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 48, step 400 / 450, loss = 0.47 (0.028 sec/batch)
# epoch 48, step 450 / 450, loss = 0.40 (0.027 sec/batch)
# Train loss: 0.328138664324 , train acc: 0.890022222222
# Validation loss: 2.20273023009, validation acc: 0.6054
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 49, step 50 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 49, step 100 / 450, loss = 0.24 (0.028 sec/batch)
# epoch 49, step 150 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 49, step 200 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 49, step 250 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 49, step 300 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 49, step 350 / 450, loss = 0.26 (0.028 sec/batch)
# epoch 49, step 400 / 450, loss = 0.37 (0.027 sec/batch)
# epoch 49, step 450 / 450, loss = 0.32 (0.027 sec/batch)
# Train loss: 0.303684701631 , train acc: 0.897
# Validation loss: 2.37193452959, validation acc: 0.6036
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 50, step 50 / 450, loss = 0.18 (0.027 sec/batch)
# epoch 50, step 100 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 50, step 150 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 50, step 200 / 450, loss = 0.35 (0.027 sec/batch)
# epoch 50, step 250 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 50, step 300 / 450, loss = 0.43 (0.027 sec/batch)
# epoch 50, step 350 / 450, loss = 0.19 (0.027 sec/batch)
# epoch 50, step 400 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 50, step 450 / 450, loss = 0.30 (0.027 sec/batch)
# Train loss: 0.298251898133 , train acc: 0.899066666667
# Validation loss: 2.38872194905, validation acc: 0.5984
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 51, step 50 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 51, step 100 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 51, step 150 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 51, step 200 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 51, step 250 / 450, loss = 0.23 (0.027 sec/batch)
# epoch 51, step 300 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 51, step 350 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 51, step 400 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 51, step 450 / 450, loss = 0.31 (0.027 sec/batch)
# Train loss: 0.298392213627 , train acc: 0.8984
# Validation loss: 2.58935965203, validation acc: 0.5946
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 52, step 50 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 52, step 100 / 450, loss = 0.33 (0.027 sec/batch)
# epoch 52, step 150 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 52, step 200 / 450, loss = 0.34 (0.027 sec/batch)
# epoch 52, step 250 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 52, step 300 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 52, step 350 / 450, loss = 0.43 (0.027 sec/batch)
# epoch 52, step 400 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 52, step 450 / 450, loss = 0.26 (0.027 sec/batch)
# Train loss: 0.273172584449 , train acc: 0.909022222222
# Validation loss: 2.66007359184, validation acc: 0.5998
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 53, step 50 / 450, loss = 0.33 (0.027 sec/batch)
# epoch 53, step 100 / 450, loss = 0.35 (0.027 sec/batch)
# epoch 53, step 150 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 53, step 200 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 53, step 250 / 450, loss = 0.21 (0.028 sec/batch)
# epoch 53, step 300 / 450, loss = 0.36 (0.028 sec/batch)
# epoch 53, step 350 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 53, step 400 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 53, step 450 / 450, loss = 0.40 (0.028 sec/batch)
# Train loss: 0.268646573159 , train acc: 0.908644444444
# Validation loss: 2.64851640072, validation acc: 0.603
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 54, step 50 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 54, step 100 / 450, loss = 0.27 (0.028 sec/batch)
# epoch 54, step 150 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 54, step 200 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 54, step 250 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 54, step 300 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 54, step 350 / 450, loss = 0.15 (0.027 sec/batch)
# epoch 54, step 400 / 450, loss = 0.34 (0.027 sec/batch)
# epoch 54, step 450 / 450, loss = 0.27 (0.027 sec/batch)
# Train loss: 0.277967395486 , train acc: 0.906111111111
# Validation loss: 2.71874448816, validation acc: 0.599
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 55, step 50 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 55, step 100 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 55, step 150 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 55, step 200 / 450, loss = 0.36 (0.027 sec/batch)
# epoch 55, step 250 / 450, loss = 0.19 (0.027 sec/batch)
# epoch 55, step 300 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 55, step 350 / 450, loss = 0.18 (0.027 sec/batch)
# epoch 55, step 400 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 55, step 450 / 450, loss = 0.34 (0.029 sec/batch)
# Train loss: 0.25233609997 , train acc: 0.915955555556
# Validation loss: 2.88588824332, validation acc: 0.6058
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 56, step 50 / 450, loss = 0.15 (0.027 sec/batch)
# epoch 56, step 100 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 56, step 150 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 56, step 200 / 450, loss = 0.28 (0.027 sec/batch)
# epoch 56, step 250 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 56, step 300 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 56, step 350 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 56, step 400 / 450, loss = 0.33 (0.027 sec/batch)
# epoch 56, step 450 / 450, loss = 0.25 (0.027 sec/batch)
# Train loss: 0.237602853621 , train acc: 0.921866666667
# Validation loss: 2.91642208554, validation acc: 0.603
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 57, step 50 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 57, step 100 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 57, step 150 / 450, loss = 0.20 (0.028 sec/batch)
# epoch 57, step 200 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 57, step 250 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 57, step 300 / 450, loss = 0.08 (0.028 sec/batch)
# epoch 57, step 350 / 450, loss = 0.31 (0.027 sec/batch)
# epoch 57, step 400 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 57, step 450 / 450, loss = 0.29 (0.027 sec/batch)
# Train loss: 0.233089225402 , train acc: 0.923311111111
# Validation loss: 3.02394060784, validation acc: 0.6058
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 58, step 50 / 450, loss = 0.15 (0.027 sec/batch)
# epoch 58, step 100 / 450, loss = 0.11 (0.027 sec/batch)
# epoch 58, step 150 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 58, step 200 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 58, step 250 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 58, step 300 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 58, step 350 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 58, step 400 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 58, step 450 / 450, loss = 0.44 (0.027 sec/batch)
# Train loss: 0.228046012003 , train acc: 0.924177777778
# Validation loss: 3.16663770935, validation acc: 0.5994
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 59, step 50 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 59, step 100 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 59, step 150 / 450, loss = 0.27 (0.027 sec/batch)
# epoch 59, step 200 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 59, step 250 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 59, step 300 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 59, step 350 / 450, loss = 0.18 (0.027 sec/batch)
# epoch 59, step 400 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 59, step 450 / 450, loss = 0.26 (0.027 sec/batch)
# Train loss: 0.21622913313 , train acc: 0.929133333333
# Validation loss: 3.28099314848, validation acc: 0.5994
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')
# epoch 60, step 50 / 450, loss = 0.25 (0.028 sec/batch)
# epoch 60, step 100 / 450, loss = 0.22 (0.028 sec/batch)
# epoch 60, step 150 / 450, loss = 0.28 (0.027 sec/batch)
# epoch 60, step 200 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 60, step 250 / 450, loss = 0.27 (0.027 sec/batch)
# epoch 60, step 300 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 60, step 350 / 450, loss = 0.23 (0.027 sec/batch)
# epoch 60, step 400 / 450, loss = 0.26 (0.027 sec/batch)
# epoch 60, step 450 / 450, loss = 0.41 (0.027 sec/batch)
# Train loss: 0.227751978214 , train acc: 0.925444444444
# Validation loss: 3.35497827565, validation acc: 0.6036
# ('Plotting in: ', './tensorflow_cifar/training_plot.pdf')

# %% [markdown]
# # Hinge

# %%
def labels_to_one_hot(Y,C):
    Yoh_ = np.zeros((Y.shape[0],C))
    Yoh_[range(Y.shape[0]),Y] = 1
    return Yoh_

with tf.device('/gpu:0'):
    sess = tf.Session()
    sess.run(init)
    plot_data = {}
    plot_data['train_loss'] = []
    plot_data['valid_loss'] = []
    plot_data['train_acc'] = []
    plot_data['valid_acc'] = []
    plot_data['lr'] = []

    num_examples = train_x.shape[0]
    num_batches = num_examples/batch_size
    #logits = pred
    #loss = cost
    #train_op = optimizer

    for epoch_num in range(1, max_epochs + 1):
        train_x, train_y = shuffle_data(train_x, train_y)
        for step in range(num_batches):
            offset = step * batch_size 
            # s ovim kodom pazite da je broj primjera djeljiv s batch_size
            batch_x = train_x[offset:(offset + batch_size), ...]
            batch_y = train_y[offset:(offset + batch_size)]
            batch_y = labels_to_one_hot(np.array(batch_y),n_classes)
#             feed_dict = {x: batch_x, y: batch_y, learning_rate: 0.05}
            feed_dict = {x: batch_x, y: batch_y}
            start_time = time.time()
            run_ops = [optimizer, cost, pred]
            ret_val = sess.run(run_ops, feed_dict=feed_dict)
            _, loss_val, logits_val = ret_val
            duration = time.time() - start_time
            if (step+1) % 50 == 0:
                sec_per_batch = float(duration)
                format_str = 'epoch %d, step %d / %d, loss = %.2f (%.3f sec/batch)'
                print format_str % (epoch_num, step+1, num_batches, loss_val, sec_per_batch)

        train_loss, train_acc = evaluate(pred, cost, train_x, labels_to_one_hot(np.array(train_y),n_classes))
        print 'Train loss: %s , train acc: %s' %(train_loss, train_acc)

        valid_loss, valid_acc = evaluate(pred, cost, valid_x, labels_to_one_hot(np.array(valid_y),n_classes))
        print 'Validation loss: %s, validation acc: %s' %(valid_loss, valid_acc) 

        plot_data['train_loss'] += [train_loss]
        plot_data['valid_loss'] += [valid_loss]
        plot_data['train_acc'] += [train_acc]
        plot_data['valid_acc'] += [valid_acc]
        plot_data['lr'] += [learning_rate.eval(session=sess)]
        #plot_data['lr'] += [0]
        plot_training_progress('./tensorflow_hinge', plot_data)
# Out:
# epoch 1, step 50 / 450, loss = 43.58 (0.027 sec/batch)
# epoch 1, step 100 / 450, loss = 44.95 (0.027 sec/batch)
# epoch 1, step 150 / 450, loss = 33.44 (0.027 sec/batch)
# epoch 1, step 200 / 450, loss = 42.47 (0.027 sec/batch)
# epoch 1, step 250 / 450, loss = 30.58 (0.027 sec/batch)
# epoch 1, step 300 / 450, loss = 29.98 (0.027 sec/batch)
# epoch 1, step 350 / 450, loss = 24.38 (0.027 sec/batch)
# epoch 1, step 400 / 450, loss = 26.75 (0.027 sec/batch)
# epoch 1, step 450 / 450, loss = 31.03 (0.027 sec/batch)
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:12: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Train loss: 27.5781781991 , train acc: 0.508555555556
# Validation loss: 29.8061583672, validation acc: 0.494
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 2, step 50 / 450, loss = 24.94 (0.027 sec/batch)
# epoch 2, step 100 / 450, loss = 21.85 (0.027 sec/batch)
# epoch 2, step 150 / 450, loss = 31.31 (0.027 sec/batch)
# epoch 2, step 200 / 450, loss = 28.07 (0.027 sec/batch)
# epoch 2, step 250 / 450, loss = 27.79 (0.027 sec/batch)
# epoch 2, step 300 / 450, loss = 20.67 (0.027 sec/batch)
# epoch 2, step 350 / 450, loss = 24.32 (0.027 sec/batch)
# epoch 2, step 400 / 450, loss = 23.64 (0.027 sec/batch)
# epoch 2, step 450 / 450, loss = 21.14 (0.027 sec/batch)
# Train loss: 20.3326627213 , train acc: 0.603911111111
# Validation loss: 23.9221563005, validation acc: 0.5798
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 3, step 50 / 450, loss = 25.25 (0.027 sec/batch)
# epoch 3, step 100 / 450, loss = 27.12 (0.027 sec/batch)
# epoch 3, step 150 / 450, loss = 24.72 (0.027 sec/batch)
# epoch 3, step 200 / 450, loss = 21.75 (0.027 sec/batch)
# epoch 3, step 250 / 450, loss = 20.35 (0.027 sec/batch)
# epoch 3, step 300 / 450, loss = 20.03 (0.028 sec/batch)
# epoch 3, step 350 / 450, loss = 20.89 (0.027 sec/batch)
# epoch 3, step 400 / 450, loss = 28.55 (0.027 sec/batch)
# epoch 3, step 450 / 450, loss = 26.94 (0.027 sec/batch)
# Train loss: 17.315082463 , train acc: 0.646755555556
# Validation loss: 22.1773730522, validation acc: 0.6116
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 4, step 50 / 450, loss = 23.47 (0.027 sec/batch)
# epoch 4, step 100 / 450, loss = 14.87 (0.027 sec/batch)
# epoch 4, step 150 / 450, loss = 21.63 (0.027 sec/batch)
# epoch 4, step 200 / 450, loss = 21.54 (0.027 sec/batch)
# epoch 4, step 250 / 450, loss = 18.53 (0.027 sec/batch)
# epoch 4, step 300 / 450, loss = 21.73 (0.027 sec/batch)
# epoch 4, step 350 / 450, loss = 17.54 (0.027 sec/batch)
# epoch 4, step 400 / 450, loss = 20.34 (0.027 sec/batch)
# epoch 4, step 450 / 450, loss = 16.70 (0.027 sec/batch)
# Train loss: 14.4621837473 , train acc: 0.6842
# Validation loss: 20.5197156666, validation acc: 0.6292
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 5, step 50 / 450, loss = 13.14 (0.027 sec/batch)
# epoch 5, step 100 / 450, loss = 12.85 (0.027 sec/batch)
# epoch 5, step 150 / 450, loss = 16.76 (0.027 sec/batch)
# epoch 5, step 200 / 450, loss = 12.65 (0.027 sec/batch)
# epoch 5, step 250 / 450, loss = 14.12 (0.027 sec/batch)
# epoch 5, step 300 / 450, loss = 18.43 (0.027 sec/batch)
# epoch 5, step 350 / 450, loss = 14.77 (0.027 sec/batch)
# epoch 5, step 400 / 450, loss = 15.37 (0.027 sec/batch)
# epoch 5, step 450 / 450, loss = 24.85 (0.027 sec/batch)
# Train loss: 13.3770812295 , train acc: 0.7008
# Validation loss: 20.8831114553, validation acc: 0.6366
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 6, step 50 / 450, loss = 12.27 (0.027 sec/batch)
# epoch 6, step 100 / 450, loss = 10.89 (0.027 sec/batch)
# epoch 6, step 150 / 450, loss = 17.98 (0.027 sec/batch)
# epoch 6, step 200 / 450, loss = 17.01 (0.027 sec/batch)
# epoch 6, step 250 / 450, loss = 16.44 (0.027 sec/batch)
# epoch 6, step 300 / 450, loss = 17.01 (0.027 sec/batch)
# epoch 6, step 350 / 450, loss = 16.68 (0.027 sec/batch)
# epoch 6, step 400 / 450, loss = 15.63 (0.027 sec/batch)
# epoch 6, step 450 / 450, loss = 13.42 (0.027 sec/batch)
# Train loss: 11.5628341558 , train acc: 0.724111111111
# Validation loss: 19.7202980953, validation acc: 0.6462
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 7, step 50 / 450, loss = 11.64 (0.027 sec/batch)
# epoch 7, step 100 / 450, loss = 5.94 (0.027 sec/batch)
# epoch 7, step 150 / 450, loss = 15.81 (0.027 sec/batch)
# epoch 7, step 200 / 450, loss = 12.43 (0.027 sec/batch)
# epoch 7, step 250 / 450, loss = 9.20 (0.027 sec/batch)
# epoch 7, step 300 / 450, loss = 14.42 (0.027 sec/batch)
# epoch 7, step 350 / 450, loss = 11.15 (0.027 sec/batch)
# epoch 7, step 400 / 450, loss = 12.26 (0.027 sec/batch)
# epoch 7, step 450 / 450, loss = 9.84 (0.027 sec/batch)
# Train loss: 9.97477417747 , train acc: 0.753177777778
# Validation loss: 19.6611982719, validation acc: 0.6598
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 8, step 50 / 450, loss = 10.56 (0.027 sec/batch)
# epoch 8, step 100 / 450, loss = 10.65 (0.027 sec/batch)
# epoch 8, step 150 / 450, loss = 7.04 (0.027 sec/batch)
# epoch 8, step 200 / 450, loss = 7.73 (0.027 sec/batch)
# epoch 8, step 250 / 450, loss = 9.24 (0.027 sec/batch)
# epoch 8, step 300 / 450, loss = 12.67 (0.027 sec/batch)
# epoch 8, step 350 / 450, loss = 11.18 (0.027 sec/batch)
# epoch 8, step 400 / 450, loss = 10.82 (0.027 sec/batch)
# epoch 8, step 450 / 450, loss = 11.99 (0.027 sec/batch)
# Train loss: 9.55133801185 , train acc: 0.755177777778
# Validation loss: 20.4548584763, validation acc: 0.6554
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 9, step 50 / 450, loss = 7.17 (0.027 sec/batch)
# epoch 9, step 100 / 450, loss = 8.71 (0.027 sec/batch)
# epoch 9, step 150 / 450, loss = 9.12 (0.027 sec/batch)
# epoch 9, step 200 / 450, loss = 9.57 (0.027 sec/batch)
# epoch 9, step 250 / 450, loss = 10.74 (0.027 sec/batch)
# epoch 9, step 300 / 450, loss = 8.33 (0.027 sec/batch)
# epoch 9, step 350 / 450, loss = 9.92 (0.027 sec/batch)
# epoch 9, step 400 / 450, loss = 9.16 (0.026 sec/batch)
# epoch 9, step 450 / 450, loss = 10.22 (0.027 sec/batch)
# Train loss: 7.88189682382 , train acc: 0.789266666667
# Validation loss: 20.0560175961, validation acc: 0.6562
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 10, step 50 / 450, loss = 7.78 (0.027 sec/batch)
# epoch 10, step 100 / 450, loss = 8.28 (0.027 sec/batch)
# epoch 10, step 150 / 450, loss = 5.76 (0.027 sec/batch)
# epoch 10, step 200 / 450, loss = 7.53 (0.027 sec/batch)
# epoch 10, step 250 / 450, loss = 5.38 (0.027 sec/batch)
# epoch 10, step 300 / 450, loss = 10.28 (0.027 sec/batch)
# epoch 10, step 350 / 450, loss = 10.69 (0.027 sec/batch)
# epoch 10, step 400 / 450, loss = 6.67 (0.027 sec/batch)
# epoch 10, step 450 / 450, loss = 11.22 (0.027 sec/batch)
# Train loss: 7.54232461342 , train acc: 0.795377777778
# Validation loss: 20.7679695297, validation acc: 0.6544
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 11, step 50 / 450, loss = 6.21 (0.027 sec/batch)
# epoch 11, step 100 / 450, loss = 4.76 (0.027 sec/batch)
# epoch 11, step 150 / 450, loss = 3.56 (0.027 sec/batch)
# epoch 11, step 200 / 450, loss = 5.89 (0.027 sec/batch)
# epoch 11, step 250 / 450, loss = 5.71 (0.027 sec/batch)
# epoch 11, step 300 / 450, loss = 7.74 (0.027 sec/batch)
# epoch 11, step 350 / 450, loss = 9.77 (0.027 sec/batch)
# epoch 11, step 400 / 450, loss = 8.00 (0.027 sec/batch)
# epoch 11, step 450 / 450, loss = 8.30 (0.027 sec/batch)
# Train loss: 6.07150354701 , train acc: 0.823111111111
# Validation loss: 21.2133922718, validation acc: 0.6558
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 12, step 50 / 450, loss = 6.65 (0.027 sec/batch)
# epoch 12, step 100 / 450, loss = 5.40 (0.027 sec/batch)
# epoch 12, step 150 / 450, loss = 6.33 (0.027 sec/batch)
# epoch 12, step 200 / 450, loss = 8.31 (0.027 sec/batch)
# epoch 12, step 250 / 450, loss = 7.48 (0.027 sec/batch)
# epoch 12, step 300 / 450, loss = 6.88 (0.027 sec/batch)
# epoch 12, step 350 / 450, loss = 6.21 (0.027 sec/batch)
# epoch 12, step 400 / 450, loss = 5.35 (0.027 sec/batch)
# epoch 12, step 450 / 450, loss = 7.80 (0.027 sec/batch)
# Train loss: 5.23848428063 , train acc: 0.844933333333
# Validation loss: 22.571393988, validation acc: 0.6582
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 13, step 50 / 450, loss = 6.59 (0.027 sec/batch)
# epoch 13, step 100 / 450, loss = 3.86 (0.027 sec/batch)
# epoch 13, step 150 / 450, loss = 5.85 (0.027 sec/batch)
# epoch 13, step 200 / 450, loss = 5.56 (0.027 sec/batch)
# epoch 13, step 250 / 450, loss = 6.59 (0.027 sec/batch)
# epoch 13, step 300 / 450, loss = 3.85 (0.027 sec/batch)
# epoch 13, step 350 / 450, loss = 6.12 (0.027 sec/batch)
# epoch 13, step 400 / 450, loss = 7.44 (0.027 sec/batch)
# epoch 13, step 450 / 450, loss = 8.29 (0.028 sec/batch)
# Train loss: 4.23986195132 , train acc: 0.868577777778
# Validation loss: 22.359828825, validation acc: 0.6726
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 14, step 50 / 450, loss = 5.24 (0.027 sec/batch)
# epoch 14, step 100 / 450, loss = 3.82 (0.027 sec/batch)
# epoch 14, step 150 / 450, loss = 3.58 (0.027 sec/batch)
# epoch 14, step 200 / 450, loss = 6.63 (0.026 sec/batch)
# epoch 14, step 250 / 450, loss = 5.22 (0.027 sec/batch)
# epoch 14, step 300 / 450, loss = 5.93 (0.027 sec/batch)
# epoch 14, step 350 / 450, loss = 5.18 (0.027 sec/batch)
# epoch 14, step 400 / 450, loss = 7.67 (0.027 sec/batch)
# epoch 14, step 450 / 450, loss = 4.96 (0.027 sec/batch)
# Train loss: 4.25954282244 , train acc: 0.868133333333
# Validation loss: 24.4939995876, validation acc: 0.6612
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 15, step 50 / 450, loss = 3.26 (0.027 sec/batch)
# epoch 15, step 100 / 450, loss = 3.40 (0.027 sec/batch)
# epoch 15, step 150 / 450, loss = 4.47 (0.027 sec/batch)
# epoch 15, step 200 / 450, loss = 3.24 (0.027 sec/batch)
# epoch 15, step 250 / 450, loss = 5.68 (0.027 sec/batch)
# epoch 15, step 300 / 450, loss = 5.36 (0.027 sec/batch)
# epoch 15, step 350 / 450, loss = 4.12 (0.027 sec/batch)
# epoch 15, step 400 / 450, loss = 5.56 (0.027 sec/batch)
# epoch 15, step 450 / 450, loss = 6.53 (0.027 sec/batch)
# Train loss: 3.75812923232 , train acc: 0.881355555556
# Validation loss: 25.0634537251, validation acc: 0.661
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 16, step 50 / 450, loss = 5.42 (0.026 sec/batch)
# epoch 16, step 100 / 450, loss = 3.18 (0.027 sec/batch)
# epoch 16, step 150 / 450, loss = 2.73 (0.027 sec/batch)
# epoch 16, step 200 / 450, loss = 2.46 (0.027 sec/batch)
# epoch 16, step 250 / 450, loss = 3.22 (0.027 sec/batch)
# epoch 16, step 300 / 450, loss = 3.81 (0.027 sec/batch)
# epoch 16, step 350 / 450, loss = 3.94 (0.027 sec/batch)
# epoch 16, step 400 / 450, loss = 4.34 (0.027 sec/batch)
# epoch 16, step 450 / 450, loss = 5.96 (0.027 sec/batch)
# Train loss: 3.42022835628 , train acc: 0.891333333333
# Validation loss: 26.9711416229, validation acc: 0.663
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 17, step 50 / 450, loss = 2.54 (0.027 sec/batch)
# epoch 17, step 100 / 450, loss = 2.26 (0.027 sec/batch)
# epoch 17, step 150 / 450, loss = 2.07 (0.027 sec/batch)
# epoch 17, step 200 / 450, loss = 2.52 (0.027 sec/batch)
# epoch 17, step 250 / 450, loss = 3.23 (0.027 sec/batch)
# epoch 17, step 300 / 450, loss = 2.66 (0.027 sec/batch)
# epoch 17, step 350 / 450, loss = 4.62 (0.026 sec/batch)
# epoch 17, step 400 / 450, loss = 3.49 (0.027 sec/batch)
# epoch 17, step 450 / 450, loss = 3.03 (0.027 sec/batch)
# Train loss: 2.53158051107 , train acc: 0.915866666667
# Validation loss: 26.8053423374, validation acc: 0.6616
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 18, step 50 / 450, loss = 3.57 (0.027 sec/batch)
# epoch 18, step 100 / 450, loss = 2.69 (0.027 sec/batch)
# epoch 18, step 150 / 450, loss = 2.76 (0.027 sec/batch)
# epoch 18, step 200 / 450, loss = 5.12 (0.027 sec/batch)
# epoch 18, step 250 / 450, loss = 2.29 (0.027 sec/batch)
# epoch 18, step 300 / 450, loss = 3.77 (0.027 sec/batch)
# epoch 18, step 350 / 450, loss = 3.09 (0.027 sec/batch)
# epoch 18, step 400 / 450, loss = 3.02 (0.027 sec/batch)
# epoch 18, step 450 / 450, loss = 2.69 (0.027 sec/batch)
# Train loss: 2.53256408808 , train acc: 0.916666666667
# Validation loss: 28.0987512508, validation acc: 0.6646
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 19, step 50 / 450, loss = 2.61 (0.027 sec/batch)
# epoch 19, step 100 / 450, loss = 2.11 (0.027 sec/batch)
# epoch 19, step 150 / 450, loss = 2.92 (0.027 sec/batch)
# epoch 19, step 200 / 450, loss = 5.30 (0.027 sec/batch)
# epoch 19, step 250 / 450, loss = 3.86 (0.027 sec/batch)
# epoch 19, step 300 / 450, loss = 3.64 (0.027 sec/batch)
# epoch 19, step 350 / 450, loss = 3.40 (0.027 sec/batch)
# epoch 19, step 400 / 450, loss = 2.52 (0.027 sec/batch)
# epoch 19, step 450 / 450, loss = 2.33 (0.027 sec/batch)
# Train loss: 2.33023142408 , train acc: 0.922933333333
# Validation loss: 29.9793548237, validation acc: 0.655
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 20, step 50 / 450, loss = 3.09 (0.027 sec/batch)
# epoch 20, step 100 / 450, loss = 1.88 (0.028 sec/batch)
# epoch 20, step 150 / 450, loss = 1.82 (0.027 sec/batch)
# epoch 20, step 200 / 450, loss = 4.06 (0.027 sec/batch)
# epoch 20, step 250 / 450, loss = 2.76 (0.027 sec/batch)
# epoch 20, step 300 / 450, loss = 2.45 (0.027 sec/batch)
# epoch 20, step 350 / 450, loss = 2.59 (0.027 sec/batch)
# epoch 20, step 400 / 450, loss = 1.42 (0.027 sec/batch)
# epoch 20, step 450 / 450, loss = 2.62 (0.027 sec/batch)
# Train loss: 2.06016254287 , train acc: 0.932044444444
# Validation loss: 31.0769099232, validation acc: 0.6602
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 21, step 50 / 450, loss = 1.43 (0.027 sec/batch)
# epoch 21, step 100 / 450, loss = 2.01 (0.027 sec/batch)
# epoch 21, step 150 / 450, loss = 2.80 (0.027 sec/batch)
# epoch 21, step 200 / 450, loss = 1.57 (0.027 sec/batch)
# epoch 21, step 250 / 450, loss = 1.41 (0.027 sec/batch)
# epoch 21, step 300 / 450, loss = 2.29 (0.027 sec/batch)
# epoch 21, step 350 / 450, loss = 2.13 (0.029 sec/batch)
# epoch 21, step 400 / 450, loss = 2.77 (0.029 sec/batch)
# epoch 21, step 450 / 450, loss = 3.50 (0.029 sec/batch)
# Train loss: 1.98388116044 , train acc: 0.933244444444
# Validation loss: 32.2003796265, validation acc: 0.651
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 22, step 50 / 450, loss = 1.46 (0.027 sec/batch)
# epoch 22, step 100 / 450, loss = 2.31 (0.027 sec/batch)
# epoch 22, step 150 / 450, loss = 1.72 (0.027 sec/batch)
# epoch 22, step 200 / 450, loss = 1.47 (0.027 sec/batch)
# epoch 22, step 250 / 450, loss = 2.45 (0.027 sec/batch)
# epoch 22, step 300 / 450, loss = 1.24 (0.027 sec/batch)
# epoch 22, step 350 / 450, loss = 2.11 (0.027 sec/batch)
# epoch 22, step 400 / 450, loss = 1.85 (0.027 sec/batch)
# epoch 22, step 450 / 450, loss = 2.39 (0.027 sec/batch)
# Train loss: 1.43611110225 , train acc: 0.951444444444
# Validation loss: 33.4322320984, validation acc: 0.6536
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 23, step 50 / 450, loss = 0.72 (0.027 sec/batch)
# epoch 23, step 100 / 450, loss = 1.34 (0.028 sec/batch)
# epoch 23, step 150 / 450, loss = 1.48 (0.027 sec/batch)
# epoch 23, step 200 / 450, loss = 1.37 (0.027 sec/batch)
# epoch 23, step 250 / 450, loss = 1.44 (0.027 sec/batch)
# epoch 23, step 300 / 450, loss = 2.13 (0.027 sec/batch)
# epoch 23, step 350 / 450, loss = 1.83 (0.027 sec/batch)
# epoch 23, step 400 / 450, loss = 2.57 (0.027 sec/batch)
# epoch 23, step 450 / 450, loss = 1.68 (0.027 sec/batch)
# Train loss: 1.27431450954 , train acc: 0.956266666667
# Validation loss: 35.4630611687, validation acc: 0.652
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 24, step 50 / 450, loss = 1.20 (0.028 sec/batch)
# epoch 24, step 100 / 450, loss = 0.91 (0.027 sec/batch)
# epoch 24, step 150 / 450, loss = 0.69 (0.027 sec/batch)
# epoch 24, step 200 / 450, loss = 2.39 (0.027 sec/batch)
# epoch 24, step 250 / 450, loss = 1.16 (0.027 sec/batch)
# epoch 24, step 300 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 24, step 350 / 450, loss = 2.79 (0.027 sec/batch)
# epoch 24, step 400 / 450, loss = 1.47 (0.027 sec/batch)
# epoch 24, step 450 / 450, loss = 0.99 (0.027 sec/batch)
# Train loss: 1.01425748664 , train acc: 0.9656
# Validation loss: 36.5333722115, validation acc: 0.657
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 25, step 50 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 25, step 100 / 450, loss = 1.21 (0.027 sec/batch)
# epoch 25, step 150 / 450, loss = 0.53 (0.027 sec/batch)
# epoch 25, step 200 / 450, loss = 1.37 (0.028 sec/batch)
# epoch 25, step 250 / 450, loss = 1.69 (0.027 sec/batch)
# epoch 25, step 300 / 450, loss = 0.87 (0.027 sec/batch)
# epoch 25, step 350 / 450, loss = 1.39 (0.026 sec/batch)
# epoch 25, step 400 / 450, loss = 1.09 (0.027 sec/batch)
# epoch 25, step 450 / 450, loss = 2.22 (0.027 sec/batch)
# Train loss: 0.922977219094 , train acc: 0.969022222222
# Validation loss: 38.447563763, validation acc: 0.6526
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 26, step 50 / 450, loss = 1.28 (0.027 sec/batch)
# epoch 26, step 100 / 450, loss = 0.47 (0.027 sec/batch)
# epoch 26, step 150 / 450, loss = 1.21 (0.027 sec/batch)
# epoch 26, step 200 / 450, loss = 0.91 (0.027 sec/batch)
# epoch 26, step 250 / 450, loss = 2.27 (0.027 sec/batch)
# epoch 26, step 300 / 450, loss = 1.21 (0.027 sec/batch)
# epoch 26, step 350 / 450, loss = 0.96 (0.027 sec/batch)
# epoch 26, step 400 / 450, loss = 1.32 (0.027 sec/batch)
# epoch 26, step 450 / 450, loss = 1.90 (0.027 sec/batch)
# Train loss: 0.86555727111 , train acc: 0.970377777778
# Validation loss: 38.4823007732, validation acc: 0.6536
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 27, step 50 / 450, loss = 0.86 (0.027 sec/batch)
# epoch 27, step 100 / 450, loss = 0.34 (0.027 sec/batch)
# epoch 27, step 150 / 450, loss = 0.95 (0.027 sec/batch)
# epoch 27, step 200 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 27, step 250 / 450, loss = 0.23 (0.027 sec/batch)
# epoch 27, step 300 / 450, loss = 1.33 (0.027 sec/batch)
# epoch 27, step 350 / 450, loss = 0.69 (0.027 sec/batch)
# epoch 27, step 400 / 450, loss = 0.82 (0.027 sec/batch)
# epoch 27, step 450 / 450, loss = 1.44 (0.027 sec/batch)
# Train loss: 0.887138102743 , train acc: 0.969844444444
# Validation loss: 39.9688058514, validation acc: 0.6514
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 28, step 50 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 28, step 100 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 28, step 150 / 450, loss = 0.66 (0.027 sec/batch)
# epoch 28, step 200 / 450, loss = 0.85 (0.027 sec/batch)
# epoch 28, step 250 / 450, loss = 1.02 (0.027 sec/batch)
# epoch 28, step 300 / 450, loss = 1.10 (0.027 sec/batch)
# epoch 28, step 350 / 450, loss = 0.57 (0.026 sec/batch)
# epoch 28, step 400 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 28, step 450 / 450, loss = 0.29 (0.027 sec/batch)
# Train loss: 0.777002045356 , train acc: 0.973288888889
# Validation loss: 42.4407463886, validation acc: 0.6536
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 29, step 50 / 450, loss = 0.47 (0.027 sec/batch)
# epoch 29, step 100 / 450, loss = 0.57 (0.027 sec/batch)
# epoch 29, step 150 / 450, loss = 0.68 (0.027 sec/batch)
# epoch 29, step 200 / 450, loss = 1.21 (0.027 sec/batch)
# epoch 29, step 250 / 450, loss = 0.73 (0.027 sec/batch)
# epoch 29, step 300 / 450, loss = 0.77 (0.027 sec/batch)
# epoch 29, step 350 / 450, loss = 1.32 (0.027 sec/batch)
# epoch 29, step 400 / 450, loss = 1.37 (0.027 sec/batch)
# epoch 29, step 450 / 450, loss = 2.08 (0.027 sec/batch)
# Train loss: 0.562061628638 , train acc: 0.981133333333
# Validation loss: 42.5214016071, validation acc: 0.6588
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 30, step 50 / 450, loss = 0.78 (0.027 sec/batch)
# epoch 30, step 100 / 450, loss = 0.14 (0.027 sec/batch)
# epoch 30, step 150 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 30, step 200 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 30, step 250 / 450, loss = 1.40 (0.027 sec/batch)
# epoch 30, step 300 / 450, loss = 0.98 (0.027 sec/batch)
# epoch 30, step 350 / 450, loss = 0.49 (0.027 sec/batch)
# epoch 30, step 400 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 30, step 450 / 450, loss = 0.76 (0.027 sec/batch)
# Train loss: 0.569168580479 , train acc: 0.98
# Validation loss: 43.8318718876, validation acc: 0.656
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 31, step 50 / 450, loss = 0.72 (0.027 sec/batch)
# epoch 31, step 100 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 31, step 150 / 450, loss = 0.19 (0.026 sec/batch)
# epoch 31, step 200 / 450, loss = 0.58 (0.027 sec/batch)
# epoch 31, step 250 / 450, loss = 1.34 (0.027 sec/batch)
# epoch 31, step 300 / 450, loss = 0.63 (0.027 sec/batch)
# epoch 31, step 350 / 450, loss = 1.17 (0.027 sec/batch)
# epoch 31, step 400 / 450, loss = 0.95 (0.027 sec/batch)
# epoch 31, step 450 / 450, loss = 0.40 (0.027 sec/batch)
# Train loss: 0.493564204534 , train acc: 0.9834
# Validation loss: 45.210687365, validation acc: 0.6524
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 32, step 50 / 450, loss = 0.32 (0.027 sec/batch)
# epoch 32, step 100 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 32, step 150 / 450, loss = 0.56 (0.027 sec/batch)
# epoch 32, step 200 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 32, step 250 / 450, loss = 0.78 (0.027 sec/batch)
# epoch 32, step 300 / 450, loss = 0.05 (0.027 sec/batch)
# epoch 32, step 350 / 450, loss = 0.06 (0.027 sec/batch)
# epoch 32, step 400 / 450, loss = 0.95 (0.027 sec/batch)
# epoch 32, step 450 / 450, loss = 0.21 (0.027 sec/batch)
# Train loss: 0.469530518553 , train acc: 0.983555555556
# Validation loss: 45.903058876, validation acc: 0.646
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 33, step 50 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 33, step 100 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 33, step 150 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 33, step 200 / 450, loss = 0.16 (0.027 sec/batch)
# epoch 33, step 250 / 450, loss = 0.08 (0.027 sec/batch)
# epoch 33, step 300 / 450, loss = 0.30 (0.027 sec/batch)
# epoch 33, step 350 / 450, loss = 1.31 (0.027 sec/batch)
# epoch 33, step 400 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 33, step 450 / 450, loss = 0.44 (0.027 sec/batch)
# Train loss: 0.330400253381 , train acc: 0.988488888889
# Validation loss: 46.2455272949, validation acc: 0.655
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 34, step 50 / 450, loss = 0.20 (0.027 sec/batch)
# epoch 34, step 100 / 450, loss = 0.54 (0.027 sec/batch)
# epoch 34, step 150 / 450, loss = 0.11 (0.027 sec/batch)
# epoch 34, step 200 / 450, loss = 0.82 (0.027 sec/batch)
# epoch 34, step 250 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 34, step 300 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 34, step 350 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 34, step 400 / 450, loss = 0.47 (0.027 sec/batch)
# epoch 34, step 450 / 450, loss = 0.86 (0.027 sec/batch)
# Train loss: 0.532361124251 , train acc: 0.981822222222
# Validation loss: 49.3693276768, validation acc: 0.6496
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 35, step 50 / 450, loss = 0.06 (0.027 sec/batch)
# epoch 35, step 100 / 450, loss = 0.43 (0.026 sec/batch)
# epoch 35, step 150 / 450, loss = 0.10 (0.027 sec/batch)
# epoch 35, step 200 / 450, loss = 0.04 (0.027 sec/batch)
# epoch 35, step 250 / 450, loss = 0.40 (0.027 sec/batch)
# epoch 35, step 300 / 450, loss = 0.92 (0.027 sec/batch)
# epoch 35, step 350 / 450, loss = 0.72 (0.027 sec/batch)
# epoch 35, step 400 / 450, loss = 0.13 (0.026 sec/batch)
# epoch 35, step 450 / 450, loss = 0.40 (0.027 sec/batch)
# Train loss: 0.427210633172 , train acc: 0.985377777778
# Validation loss: 48.7768841911, validation acc: 0.6538
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 36, step 50 / 450, loss = 0.10 (0.027 sec/batch)
# epoch 36, step 100 / 450, loss = 0.39 (0.027 sec/batch)
# epoch 36, step 150 / 450, loss = 0.02 (0.027 sec/batch)
# epoch 36, step 200 / 450, loss = 0.41 (0.027 sec/batch)
# epoch 36, step 250 / 450, loss = 0.07 (0.027 sec/batch)
# epoch 36, step 300 / 450, loss = 0.35 (0.027 sec/batch)
# epoch 36, step 350 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 36, step 400 / 450, loss = 0.38 (0.027 sec/batch)
# epoch 36, step 450 / 450, loss = 0.31 (0.027 sec/batch)
# Train loss: 0.209059478082 , train acc: 0.993066666667
# Validation loss: 48.2166480156, validation acc: 0.6558
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 37, step 50 / 450, loss = 0.04 (0.027 sec/batch)
# epoch 37, step 100 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 37, step 150 / 450, loss = 0.10 (0.027 sec/batch)
# epoch 37, step 200 / 450, loss = 0.11 (0.027 sec/batch)
# epoch 37, step 250 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 37, step 300 / 450, loss = 0.29 (0.027 sec/batch)
# epoch 37, step 350 / 450, loss = 0.38 (0.028 sec/batch)
# epoch 37, step 400 / 450, loss = 0.37 (0.027 sec/batch)
# epoch 37, step 450 / 450, loss = 0.19 (0.027 sec/batch)
# Train loss: 0.185222133382 , train acc: 0.993955555556
# Validation loss: 50.0009660557, validation acc: 0.652
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 38, step 50 / 450, loss = 0.34 (0.026 sec/batch)
# epoch 38, step 100 / 450, loss = 0.22 (0.026 sec/batch)
# epoch 38, step 150 / 450, loss = 0.12 (0.026 sec/batch)
# epoch 38, step 200 / 450, loss = 0.49 (0.026 sec/batch)
# epoch 38, step 250 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 38, step 300 / 450, loss = 0.09 (0.027 sec/batch)
# epoch 38, step 350 / 450, loss = 0.24 (0.027 sec/batch)
# epoch 38, step 400 / 450, loss = 0.74 (0.027 sec/batch)
# epoch 38, step 450 / 450, loss = 0.43 (0.026 sec/batch)
# Train loss: 0.253377864626 , train acc: 0.991444444444
# Validation loss: 49.8663662273, validation acc: 0.6514
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 39, step 50 / 450, loss = 0.30 (0.026 sec/batch)
# epoch 39, step 100 / 450, loss = 0.08 (0.027 sec/batch)
# epoch 39, step 150 / 450, loss = 0.20 (0.026 sec/batch)
# epoch 39, step 200 / 450, loss = 0.05 (0.026 sec/batch)
# epoch 39, step 250 / 450, loss = 0.10 (0.026 sec/batch)
# epoch 39, step 300 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 39, step 350 / 450, loss = 0.56 (0.026 sec/batch)
# epoch 39, step 400 / 450, loss = 0.08 (0.026 sec/batch)
# epoch 39, step 450 / 450, loss = 0.14 (0.027 sec/batch)
# Train loss: 0.270612319946 , train acc: 0.990644444444
# Validation loss: 51.4233974545, validation acc: 0.6574
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 40, step 50 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 40, step 100 / 450, loss = 0.81 (0.026 sec/batch)
# epoch 40, step 150 / 450, loss = 1.25 (0.027 sec/batch)
# epoch 40, step 200 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 40, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 40, step 300 / 450, loss = 0.21 (0.028 sec/batch)
# epoch 40, step 350 / 450, loss = 0.52 (0.026 sec/batch)
# epoch 40, step 400 / 450, loss = 0.36 (0.027 sec/batch)
# epoch 40, step 450 / 450, loss = 0.33 (0.027 sec/batch)
# Train loss: 0.194768048901 , train acc: 0.993555555556
# Validation loss: 53.698541827, validation acc: 0.6524
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 41, step 50 / 450, loss = 0.14 (0.026 sec/batch)
# epoch 41, step 100 / 450, loss = 0.18 (0.027 sec/batch)
# epoch 41, step 150 / 450, loss = 0.23 (0.027 sec/batch)
# epoch 41, step 200 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 41, step 250 / 450, loss = 0.34 (0.026 sec/batch)
# epoch 41, step 300 / 450, loss = 0.12 (0.026 sec/batch)
# epoch 41, step 350 / 450, loss = 0.14 (0.027 sec/batch)
# epoch 41, step 400 / 450, loss = 0.09 (0.026 sec/batch)
# epoch 41, step 450 / 450, loss = 0.11 (0.027 sec/batch)
# Train loss: 0.151048472977 , train acc: 0.995
# Validation loss: 53.5832030945, validation acc: 0.6536
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 42, step 50 / 450, loss = 0.06 (0.027 sec/batch)
# epoch 42, step 100 / 450, loss = 0.07 (0.026 sec/batch)
# epoch 42, step 150 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 42, step 200 / 450, loss = 0.10 (0.026 sec/batch)
# epoch 42, step 250 / 450, loss = 0.29 (0.026 sec/batch)
# epoch 42, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 42, step 350 / 450, loss = 0.04 (0.027 sec/batch)
# epoch 42, step 400 / 450, loss = 0.23 (0.027 sec/batch)
# epoch 42, step 450 / 450, loss = 0.00 (0.026 sec/batch)
# Train loss: 0.107158277681 , train acc: 0.996533333333
# Validation loss: 53.1078242405, validation acc: 0.6518
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 43, step 50 / 450, loss = 0.19 (0.027 sec/batch)
# epoch 43, step 100 / 450, loss = 0.15 (0.027 sec/batch)
# epoch 43, step 150 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 43, step 200 / 450, loss = 0.19 (0.027 sec/batch)
# epoch 43, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 43, step 300 / 450, loss = 0.25 (0.027 sec/batch)
# epoch 43, step 350 / 450, loss = 0.03 (0.027 sec/batch)
# epoch 43, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 43, step 450 / 450, loss = 0.10 (0.026 sec/batch)
# Train loss: 0.108089721129 , train acc: 0.996155555556
# Validation loss: 52.5509446796, validation acc: 0.6638
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 44, step 50 / 450, loss = 0.05 (0.027 sec/batch)
# epoch 44, step 100 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 44, step 150 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 44, step 200 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 44, step 250 / 450, loss = 0.01 (0.026 sec/batch)
# epoch 44, step 300 / 450, loss = 0.16 (0.027 sec/batch)
# epoch 44, step 350 / 450, loss = 0.13 (0.026 sec/batch)
# epoch 44, step 400 / 450, loss = 0.05 (0.027 sec/batch)
# epoch 44, step 450 / 450, loss = 0.33 (0.027 sec/batch)
# Train loss: 0.0825229540507 , train acc: 0.997355555556
# Validation loss: 54.55024809, validation acc: 0.6596
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 45, step 50 / 450, loss = 0.03 (0.026 sec/batch)
# epoch 45, step 100 / 450, loss = 0.02 (0.026 sec/batch)
# epoch 45, step 150 / 450, loss = 0.01 (0.027 sec/batch)
# epoch 45, step 200 / 450, loss = 0.04 (0.027 sec/batch)
# epoch 45, step 250 / 450, loss = 0.44 (0.027 sec/batch)
# epoch 45, step 300 / 450, loss = 0.10 (0.026 sec/batch)
# epoch 45, step 350 / 450, loss = 0.07 (0.027 sec/batch)
# epoch 45, step 400 / 450, loss = 0.01 (0.028 sec/batch)
# epoch 45, step 450 / 450, loss = 0.03 (0.026 sec/batch)
# Train loss: 0.129697490141 , train acc: 0.995733333333
# Validation loss: 55.4669328083, validation acc: 0.6542
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 46, step 50 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 46, step 100 / 450, loss = 0.62 (0.027 sec/batch)
# epoch 46, step 150 / 450, loss = 0.19 (0.026 sec/batch)
# epoch 46, step 200 / 450, loss = 0.60 (0.027 sec/batch)
# epoch 46, step 250 / 450, loss = 0.26 (0.026 sec/batch)
# epoch 46, step 300 / 450, loss = 0.21 (0.027 sec/batch)
# epoch 46, step 350 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 46, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 46, step 450 / 450, loss = 0.22 (0.027 sec/batch)
# Train loss: 0.104314503098 , train acc: 0.996733333333
# Validation loss: 54.6752798714, validation acc: 0.6542
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 47, step 50 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 47, step 100 / 450, loss = 0.13 (0.027 sec/batch)
# epoch 47, step 150 / 450, loss = 0.21 (0.026 sec/batch)
# epoch 47, step 200 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 47, step 250 / 450, loss = 0.14 (0.027 sec/batch)
# epoch 47, step 300 / 450, loss = 0.03 (0.026 sec/batch)
# epoch 47, step 350 / 450, loss = 0.36 (0.027 sec/batch)
# epoch 47, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 47, step 450 / 450, loss = 0.00 (0.027 sec/batch)
# Train loss: 0.0955376894633 , train acc: 0.996688888889
# Validation loss: 56.3897163879, validation acc: 0.6596
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 48, step 50 / 450, loss = 0.06 (0.026 sec/batch)
# epoch 48, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 48, step 150 / 450, loss = 0.26 (0.026 sec/batch)
# epoch 48, step 200 / 450, loss = 0.48 (0.026 sec/batch)
# epoch 48, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 48, step 300 / 450, loss = 0.24 (0.026 sec/batch)
# epoch 48, step 350 / 450, loss = 0.08 (0.027 sec/batch)
# epoch 48, step 400 / 450, loss = 0.03 (0.027 sec/batch)
# epoch 48, step 450 / 450, loss = 0.11 (0.027 sec/batch)
# Train loss: 0.0759788669586 , train acc: 0.9976
# Validation loss: 57.0399206253, validation acc: 0.6566
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 49, step 50 / 450, loss = 0.00 (0.028 sec/batch)
# epoch 49, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 49, step 150 / 450, loss = 0.06 (0.026 sec/batch)
# epoch 49, step 200 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 49, step 250 / 450, loss = 0.03 (0.027 sec/batch)
# epoch 49, step 300 / 450, loss = 0.10 (0.027 sec/batch)
# epoch 49, step 350 / 450, loss = 0.05 (0.026 sec/batch)
# epoch 49, step 400 / 450, loss = 0.10 (0.027 sec/batch)
# epoch 49, step 450 / 450, loss = 0.01 (0.026 sec/batch)
# Train loss: 0.061734695816 , train acc: 0.998022222222
# Validation loss: 57.713453183, validation acc: 0.661
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 50, step 50 / 450, loss = 0.02 (0.027 sec/batch)
# epoch 50, step 100 / 450, loss = 0.03 (0.027 sec/batch)
# epoch 50, step 150 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 50, step 200 / 450, loss = 0.33 (0.026 sec/batch)
# epoch 50, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 50, step 300 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 50, step 350 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 50, step 400 / 450, loss = 0.14 (0.027 sec/batch)
# epoch 50, step 450 / 450, loss = 0.21 (0.027 sec/batch)
# Train loss: 0.0300748972575 , train acc: 0.999177777778
# Validation loss: 57.1471044041, validation acc: 0.6656
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 51, step 50 / 450, loss = 0.00 (0.028 sec/batch)
# epoch 51, step 100 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 51, step 150 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 51, step 200 / 450, loss = 0.03 (0.027 sec/batch)
# epoch 51, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 51, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 51, step 350 / 450, loss = 0.05 (0.026 sec/batch)
# epoch 51, step 400 / 450, loss = 0.02 (0.026 sec/batch)
# epoch 51, step 450 / 450, loss = 0.00 (0.026 sec/batch)
# Train loss: 0.0358389635722 , train acc: 0.999
# Validation loss: 57.6088940712, validation acc: 0.6568
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 52, step 50 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 52, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 52, step 150 / 450, loss = 0.52 (0.027 sec/batch)
# epoch 52, step 200 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 52, step 250 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 52, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 52, step 350 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 52, step 400 / 450, loss = 0.04 (0.027 sec/batch)
# epoch 52, step 450 / 450, loss = 0.00 (0.027 sec/batch)
# Train loss: 0.0286051443312 , train acc: 0.999222222222
# Validation loss: 59.255153162, validation acc: 0.662
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 53, step 50 / 450, loss = 0.04 (0.027 sec/batch)
# epoch 53, step 100 / 450, loss = 0.06 (0.027 sec/batch)
# epoch 53, step 150 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 53, step 200 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 53, step 250 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 53, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 53, step 350 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 53, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 53, step 450 / 450, loss = 0.07 (0.027 sec/batch)
# Train loss: 0.0372033088684 , train acc: 0.998844444444
# Validation loss: 59.1546009453, validation acc: 0.659
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 54, step 50 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 54, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 54, step 150 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 54, step 200 / 450, loss = 0.06 (0.028 sec/batch)
# epoch 54, step 250 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 54, step 300 / 450, loss = 0.01 (0.027 sec/batch)
# epoch 54, step 350 / 450, loss = 0.01 (0.027 sec/batch)
# epoch 54, step 400 / 450, loss = 0.06 (0.026 sec/batch)
# epoch 54, step 450 / 450, loss = 0.00 (0.026 sec/batch)
# Train loss: 0.0245224483914 , train acc: 0.999466666667
# Validation loss: 58.6085940273, validation acc: 0.6596
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 55, step 50 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 55, step 100 / 450, loss = 0.00 (0.028 sec/batch)
# epoch 55, step 150 / 450, loss = 0.05 (0.026 sec/batch)
# epoch 55, step 200 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 55, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 55, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 55, step 350 / 450, loss = 0.22 (0.027 sec/batch)
# epoch 55, step 400 / 450, loss = 0.06 (0.027 sec/batch)
# epoch 55, step 450 / 450, loss = 0.16 (0.027 sec/batch)
# Train loss: 0.0419968401591 , train acc: 0.998711111111
# Validation loss: 59.0580229183, validation acc: 0.6548
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 56, step 50 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 56, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 56, step 150 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 56, step 200 / 450, loss = 0.24 (0.026 sec/batch)
# epoch 56, step 250 / 450, loss = 0.23 (0.026 sec/batch)
# epoch 56, step 300 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 56, step 350 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 56, step 400 / 450, loss = 0.02 (0.027 sec/batch)
# epoch 56, step 450 / 450, loss = 0.00 (0.027 sec/batch)
# Train loss: 0.0277147297329 , train acc: 0.999133333333
# Validation loss: 58.6933817627, validation acc: 0.6564
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 57, step 50 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 57, step 100 / 450, loss = 0.17 (0.027 sec/batch)
# epoch 57, step 150 / 450, loss = 0.21 (0.026 sec/batch)
# epoch 57, step 200 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 57, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 57, step 300 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 57, step 350 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 57, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 57, step 450 / 450, loss = 0.00 (0.026 sec/batch)
# Train loss: 0.0536864179823 , train acc: 0.9982
# Validation loss: 60.8456050804, validation acc: 0.6556
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 58, step 50 / 450, loss = 0.08 (0.027 sec/batch)
# epoch 58, step 100 / 450, loss = 0.02 (0.026 sec/batch)
# epoch 58, step 150 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 58, step 200 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 58, step 250 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 58, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 58, step 350 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 58, step 400 / 450, loss = 0.10 (0.026 sec/batch)
# epoch 58, step 450 / 450, loss = 0.07 (0.027 sec/batch)
# Train loss: 0.0279859834459 , train acc: 0.999222222222
# Validation loss: 61.2033744652, validation acc: 0.6544
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 59, step 50 / 450, loss = 0.01 (0.027 sec/batch)
# epoch 59, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 59, step 150 / 450, loss = 0.00 (0.028 sec/batch)
# epoch 59, step 200 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 59, step 250 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 59, step 300 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 59, step 350 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 59, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 59, step 450 / 450, loss = 0.05 (0.027 sec/batch)
# Train loss: 0.0158632735358 , train acc: 0.999422222222
# Validation loss: 60.7548026962, validation acc: 0.6534
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')
# epoch 60, step 50 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 60, step 100 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 60, step 150 / 450, loss = 0.05 (0.027 sec/batch)
# epoch 60, step 200 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 60, step 250 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 60, step 300 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 60, step 350 / 450, loss = 0.00 (0.026 sec/batch)
# epoch 60, step 400 / 450, loss = 0.00 (0.027 sec/batch)
# epoch 60, step 450 / 450, loss = 0.00 (0.027 sec/batch)
# Train loss: 0.0112103730943 , train acc: 0.999688888889
# Validation loss: 60.0861323532, validation acc: 0.6562
# ('Plotting in: ', './tensorflow_hinge/training_plot.pdf')

# %%
saver = tf.train.Saver()
saver.save(sess,"cifar.model-hinge1.ckpt")
# Out:
# 'cifar.model-hinge.ckpt'

# %%
def labels_to_one_hot(Y,C):
    Yoh_ = np.zeros((Y.shape[0],C))
    Yoh_[range(Y.shape[0]),Y] = 1
    return Yoh_

sess = tf.Session()
sess.run(init)
step = 1
Yoh_ = labels_to_one_hot(np.array(test_y),n_classes)
num_examples = train_x.shape[0]
num_batches = num_examples/batch_size
for epoch in range(1, max_epochs):
    if epoch in learning_policy:
        lr = learning_policy[epoch]
    
    train_x,train_y = shuffle_data(train_x,train_y)
    for i in range (num_batches):
        batch_x = train_x[i*batch_size:(i+1)*batch_size,:,:,:]
        batch_y = labels_to_one_hot(np.array(train_y[i*batch_size:(i+1)*batch_size]), n_classes)
#         _, loss, acc= sess.run([optimizer,cost, accuracy], feed_dict={x: batch_x, y: batch_y, learning_rate: lr})
        _, loss, acc= sess.run([optimizer,cost, accuracy], feed_dict={x: batch_x, y: batch_y})
        if i % print_every_num_batches ==0:
            print "Epoch %d, step %d/%d, batch loss = %.2f batch_acc = %s, acc = %s" % (epoch, i*batch_size, num_examples, loss, acc, sess.run(accuracy, feed_dict={x:test_x, y: Yoh_ }))
        if i % draw_filter == 0:
            draw_conv_filters(epoch, i*batch_size, sess.run(weights['wc1']), SAVE_DIR)
            
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_x,
                                  y: labels_to_one_hot(test_y,n_classes)})
# Out:
# Epoch 1, step 0/45000, batch loss = 3.42 batch_acc = 0.13, acc = 0.1
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:15: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Epoch 1, step 2000/45000, batch loss = 2.42 batch_acc = 0.18, acc = 0.1966
# Epoch 1, step 4000/45000, batch loss = 2.05 batch_acc = 0.22, acc = 0.2414
# Epoch 1, step 6000/45000, batch loss = 2.03 batch_acc = 0.23, acc = 0.284
# Epoch 1, step 8000/45000, batch loss = 1.82 batch_acc = 0.29, acc = 0.265
# Epoch 1, step 10000/45000, batch loss = 1.92 batch_acc = 0.23, acc = 0.3087
# Epoch 1, step 12000/45000, batch loss = 2.24 batch_acc = 0.23, acc = 0.3362
# Epoch 1, step 14000/45000, batch loss = 1.68 batch_acc = 0.37, acc = 0.341
# Epoch 1, step 16000/45000, batch loss = 1.80 batch_acc = 0.3, acc = 0.3549
# Epoch 1, step 18000/45000, batch loss = 1.89 batch_acc = 0.36, acc = 0.3443
# Epoch 1, step 20000/45000, batch loss = 1.81 batch_acc = 0.37, acc = 0.3263
# Epoch 1, step 22000/45000, batch loss = 1.96 batch_acc = 0.26, acc = 0.3456
# Epoch 1, step 24000/45000, batch loss = 1.69 batch_acc = 0.32, acc = 0.3565
# Epoch 1, step 26000/45000, batch loss = 1.75 batch_acc = 0.29, acc = 0.3373
# Epoch 1, step 28000/45000, batch loss = 1.83 batch_acc = 0.28, acc = 0.3336
# Epoch 1, step 30000/45000, batch loss = 1.80 batch_acc = 0.37, acc = 0.3505
# Epoch 1, step 32000/45000, batch loss = 1.97 batch_acc = 0.29, acc = 0.3717
# Epoch 1, step 34000/45000, batch loss = 1.45 batch_acc = 0.56, acc = 0.3909
# Epoch 1, step 36000/45000, batch loss = 1.71 batch_acc = 0.37, acc = 0.3545
# Epoch 1, step 38000/45000, batch loss = 1.74 batch_acc = 0.32, acc = 0.3895
# Epoch 1, step 40000/45000, batch loss = 1.88 batch_acc = 0.3, acc = 0.3954
# Epoch 1, step 42000/45000, batch loss = 1.75 batch_acc = 0.36, acc = 0.3663
# Epoch 1, step 44000/45000, batch loss = 1.75 batch_acc = 0.37, acc = 0.4045
# Epoch 2, step 0/45000, batch loss = 1.74 batch_acc = 0.4, acc = 0.3912
# Epoch 2, step 2000/45000, batch loss = 1.55 batch_acc = 0.41, acc = 0.3862
# Epoch 2, step 4000/45000, batch loss = 1.79 batch_acc = 0.28, acc = 0.4065
# Epoch 2, step 6000/45000, batch loss = 1.64 batch_acc = 0.41, acc = 0.4067
# Epoch 2, step 8000/45000, batch loss = 1.76 batch_acc = 0.36, acc = 0.4132
# Epoch 2, step 10000/45000, batch loss = 1.67 batch_acc = 0.39, acc = 0.4049
# Epoch 2, step 12000/45000, batch loss = 1.85 batch_acc = 0.34, acc = 0.3773
# Epoch 2, step 14000/45000, batch loss = 1.68 batch_acc = 0.4, acc = 0.3953
# Epoch 2, step 16000/45000, batch loss = 1.70 batch_acc = 0.35, acc = 0.4011
# Epoch 2, step 18000/45000, batch loss = 1.64 batch_acc = 0.37, acc = 0.406
# Epoch 2, step 20000/45000, batch loss = 1.65 batch_acc = 0.39, acc = 0.4147
# Epoch 2, step 22000/45000, batch loss = 1.68 batch_acc = 0.37, acc = 0.3745
# Epoch 2, step 24000/45000, batch loss = 1.75 batch_acc = 0.38, acc = 0.4
# Epoch 2, step 26000/45000, batch loss = 1.67 batch_acc = 0.32, acc = 0.3964
# Epoch 2, step 28000/45000, batch loss = 1.69 batch_acc = 0.38, acc = 0.4169
# Epoch 2, step 30000/45000, batch loss = 1.63 batch_acc = 0.41, acc = 0.4151
# Epoch 2, step 32000/45000, batch loss = 1.80 batch_acc = 0.37, acc = 0.368
# Epoch 2, step 34000/45000, batch loss = 1.42 batch_acc = 0.48, acc = 0.4381
# Epoch 2, step 36000/45000, batch loss = 1.86 batch_acc = 0.37, acc = 0.4126
# Epoch 2, step 38000/45000, batch loss = 1.51 batch_acc = 0.46, acc = 0.4316
# Epoch 2, step 40000/45000, batch loss = 1.68 batch_acc = 0.38, acc = 0.4197
# Epoch 2, step 42000/45000, batch loss = 1.52 batch_acc = 0.48, acc = 0.4171
# Epoch 2, step 44000/45000, batch loss = 1.62 batch_acc = 0.39, acc = 0.4008
# Epoch 3, step 0/45000, batch loss = 1.59 batch_acc = 0.38, acc = 0.4259
# Epoch 3, step 2000/45000, batch loss = 1.56 batch_acc = 0.48, acc = 0.419
# Epoch 3, step 4000/45000, batch loss = 1.72 batch_acc = 0.42, acc = 0.4346
# Epoch 3, step 6000/45000, batch loss = 1.43 batch_acc = 0.46, acc = 0.4387
# Epoch 3, step 8000/45000, batch loss = 1.55 batch_acc = 0.42, acc = 0.4078
# Epoch 3, step 10000/45000, batch loss = 1.62 batch_acc = 0.36, acc = 0.4173
# Epoch 3, step 12000/45000, batch loss = 1.44 batch_acc = 0.5, acc = 0.442
# Epoch 3, step 14000/45000, batch loss = 1.31 batch_acc = 0.54, acc = 0.4485
# Epoch 3, step 16000/45000, batch loss = 1.57 batch_acc = 0.41, acc = 0.421
# Epoch 3, step 18000/45000, batch loss = 1.54 batch_acc = 0.45, acc = 0.4438
# Epoch 3, step 20000/45000, batch loss = 1.56 batch_acc = 0.4, acc = 0.4292
# Epoch 3, step 22000/45000, batch loss = 1.76 batch_acc = 0.36, acc = 0.4284
# Epoch 3, step 24000/45000, batch loss = 1.53 batch_acc = 0.47, acc = 0.4394
# Epoch 3, step 26000/45000, batch loss = 1.65 batch_acc = 0.44, acc = 0.4381
# Epoch 3, step 28000/45000, batch loss = 1.50 batch_acc = 0.49, acc = 0.4371
# Epoch 3, step 30000/45000, batch loss = 1.65 batch_acc = 0.46, acc = 0.4561
# Epoch 3, step 32000/45000, batch loss = 1.69 batch_acc = 0.41, acc = 0.4451
# Epoch 3, step 34000/45000, batch loss = 1.71 batch_acc = 0.41, acc = 0.4173
# Epoch 3, step 36000/45000, batch loss = 1.81 batch_acc = 0.32, acc = 0.4011
# Epoch 3, step 38000/45000, batch loss = 1.48 batch_acc = 0.47, acc = 0.4377
# Epoch 3, step 40000/45000, batch loss = 1.64 batch_acc = 0.36, acc = 0.439
# Epoch 3, step 42000/45000, batch loss = 1.53 batch_acc = 0.47, acc = 0.4414
# Epoch 3, step 44000/45000, batch loss = 1.46 batch_acc = 0.47, acc = 0.4579
# Epoch 4, step 0/45000, batch loss = 1.53 batch_acc = 0.47, acc = 0.4263
# Epoch 4, step 2000/45000, batch loss = 1.54 batch_acc = 0.42, acc = 0.4492
# Epoch 4, step 4000/45000, batch loss = 1.42 batch_acc = 0.47, acc = 0.4609
# Epoch 4, step 6000/45000, batch loss = 1.55 batch_acc = 0.49, acc = 0.4485
# Epoch 4, step 8000/45000, batch loss = 1.60 batch_acc = 0.49, acc = 0.4565
# Epoch 4, step 10000/45000, batch loss = 1.42 batch_acc = 0.43, acc = 0.4456
# Epoch 4, step 12000/45000, batch loss = 1.72 batch_acc = 0.36, acc = 0.4393
# Epoch 4, step 14000/45000, batch loss = 1.49 batch_acc = 0.45, acc = 0.4542
# Epoch 4, step 16000/45000, batch loss = 1.82 batch_acc = 0.4, acc = 0.4383
# Epoch 4, step 18000/45000, batch loss = 1.45 batch_acc = 0.56, acc = 0.4573
# Epoch 4, step 20000/45000, batch loss = 1.34 batch_acc = 0.5, acc = 0.4487
# Epoch 4, step 22000/45000, batch loss = 1.75 batch_acc = 0.39, acc = 0.4471
# Epoch 4, step 24000/45000, batch loss = 1.60 batch_acc = 0.42, acc = 0.4624
# Epoch 4, step 26000/45000, batch loss = 1.55 batch_acc = 0.49, acc = 0.4562
# Epoch 4, step 28000/45000, batch loss = 1.56 batch_acc = 0.48, acc = 0.4742
# Epoch 4, step 30000/45000, batch loss = 1.49 batch_acc = 0.46, acc = 0.4622
# Epoch 4, step 32000/45000, batch loss = 1.44 batch_acc = 0.48, acc = 0.4562
# Epoch 4, step 34000/45000, batch loss = 1.59 batch_acc = 0.4, acc = 0.4376
# Epoch 4, step 36000/45000, batch loss = 1.29 batch_acc = 0.49, acc = 0.458
# Epoch 4, step 38000/45000, batch loss = 1.45 batch_acc = 0.55, acc = 0.462
# Epoch 4, step 40000/45000, batch loss = 1.42 batch_acc = 0.51, acc = 0.4548
# Epoch 4, step 42000/45000, batch loss = 1.42 batch_acc = 0.49, acc = 0.4466
# Epoch 4, step 44000/45000, batch loss = 1.62 batch_acc = 0.41, acc = 0.4654
# Epoch 5, step 0/45000, batch loss = 1.40 batch_acc = 0.53, acc = 0.4637
# Epoch 5, step 2000/45000, batch loss = 1.28 batch_acc = 0.55, acc = 0.4642
# Epoch 5, step 4000/45000, batch loss = 1.46 batch_acc = 0.4, acc = 0.4646
# Epoch 5, step 6000/45000, batch loss = 1.45 batch_acc = 0.48, acc = 0.4697
# Epoch 5, step 8000/45000, batch loss = 1.49 batch_acc = 0.5, acc = 0.4772
# Epoch 5, step 10000/45000, batch loss = 1.47 batch_acc = 0.45, acc = 0.4535
# Epoch 5, step 12000/45000, batch loss = 1.43 batch_acc = 0.48, acc = 0.463
# Epoch 5, step 14000/45000, batch loss = 1.30 batch_acc = 0.53, acc = 0.4713
# Epoch 5, step 16000/45000, batch loss = 1.40 batch_acc = 0.46, acc = 0.4637
# Epoch 5, step 18000/45000, batch loss = 1.67 batch_acc = 0.44, acc = 0.4572
# Epoch 5, step 20000/45000, batch loss = 1.39 batch_acc = 0.49, acc = 0.4683
# Epoch 5, step 22000/45000, batch loss = 1.52 batch_acc = 0.46, acc = 0.4746
# Epoch 5, step 24000/45000, batch loss = 1.46 batch_acc = 0.42, acc = 0.4767
# Epoch 5, step 26000/45000, batch loss = 1.59 batch_acc = 0.53, acc = 0.5006
# Epoch 5, step 28000/45000, batch loss = 1.52 batch_acc = 0.48, acc = 0.471
# Epoch 5, step 30000/45000, batch loss = 1.47 batch_acc = 0.48, acc = 0.4687
# Epoch 5, step 32000/45000, batch loss = 1.55 batch_acc = 0.45, acc = 0.4758
# Epoch 5, step 34000/45000, batch loss = 1.50 batch_acc = 0.53, acc = 0.4556
# Epoch 5, step 36000/45000, batch loss = 1.49 batch_acc = 0.46, acc = 0.48
# Epoch 5, step 38000/45000, batch loss = 1.56 batch_acc = 0.45, acc = 0.4636
# Epoch 5, step 40000/45000, batch loss = 1.37 batch_acc = 0.51, acc = 0.4936
# Epoch 5, step 42000/45000, batch loss = 1.58 batch_acc = 0.51, acc = 0.4775
# Epoch 5, step 44000/45000, batch loss = 1.66 batch_acc = 0.41, acc = 0.4756
# Epoch 6, step 0/45000, batch loss = 1.36 batch_acc = 0.54, acc = 0.4903
# Epoch 6, step 2000/45000, batch loss = 1.31 batch_acc = 0.53, acc = 0.4987
# Epoch 6, step 4000/45000, batch loss = 1.45 batch_acc = 0.46, acc = 0.4669
# Epoch 6, step 6000/45000, batch loss = 1.51 batch_acc = 0.4, acc = 0.4712
# Epoch 6, step 8000/45000, batch loss = 1.52 batch_acc = 0.38, acc = 0.4681
# Epoch 6, step 10000/45000, batch loss = 1.28 batch_acc = 0.55, acc = 0.4893
# Epoch 6, step 12000/45000, batch loss = 1.18 batch_acc = 0.61, acc = 0.4877
# Epoch 6, step 14000/45000, batch loss = 1.38 batch_acc = 0.49, acc = 0.4781
# Epoch 6, step 16000/45000, batch loss = 1.40 batch_acc = 0.49, acc = 0.4843
# Epoch 6, step 18000/45000, batch loss = 1.36 batch_acc = 0.46, acc = 0.4852
# Epoch 6, step 20000/45000, batch loss = 1.42 batch_acc = 0.51, acc = 0.4712
# Epoch 6, step 22000/45000, batch loss = 1.46 batch_acc = 0.4, acc = 0.4722
# Epoch 6, step 24000/45000, batch loss = 1.46 batch_acc = 0.46, acc = 0.4779
# Epoch 6, step 26000/45000, batch loss = 1.35 batch_acc = 0.51, acc = 0.4826
# Epoch 6, step 28000/45000, batch loss = 1.49 batch_acc = 0.47, acc = 0.4938
# Epoch 6, step 30000/45000, batch loss = 1.25 batch_acc = 0.59, acc = 0.5106
# Epoch 6, step 32000/45000, batch loss = 1.60 batch_acc = 0.42, acc = 0.4625
# Epoch 6, step 34000/45000, batch loss = 1.26 batch_acc = 0.54, acc = 0.4987
# Epoch 6, step 36000/45000, batch loss = 1.34 batch_acc = 0.54, acc = 0.4758
# Epoch 6, step 38000/45000, batch loss = 1.29 batch_acc = 0.52, acc = 0.4928
# Epoch 6, step 40000/45000, batch loss = 1.25 batch_acc = 0.56, acc = 0.4988
# Epoch 6, step 42000/45000, batch loss = 1.31 batch_acc = 0.59, acc = 0.4813
# Epoch 6, step 44000/45000, batch loss = 1.52 batch_acc = 0.5, acc = 0.4936
# Epoch 7, step 0/45000, batch loss = 1.32 batch_acc = 0.54, acc = 0.4919
# Epoch 7, step 2000/45000, batch loss = 1.33 batch_acc = 0.49, acc = 0.4951
# Epoch 7, step 4000/45000, batch loss = 1.37 batch_acc = 0.49, acc = 0.4847
# Epoch 7, step 6000/45000, batch loss = 1.54 batch_acc = 0.46, acc = 0.472
# Epoch 7, step 8000/45000, batch loss = 1.26 batch_acc = 0.54, acc = 0.4962
# Epoch 7, step 10000/45000, batch loss = 1.39 batch_acc = 0.54, acc = 0.5087
# Epoch 7, step 12000/45000, batch loss = 1.56 batch_acc = 0.53, acc = 0.4856
# Epoch 7, step 14000/45000, batch loss = 1.33 batch_acc = 0.53, acc = 0.4979
# Epoch 7, step 16000/45000, batch loss = 1.38 batch_acc = 0.53, acc = 0.5058
# Epoch 7, step 18000/45000, batch loss = 1.36 batch_acc = 0.47, acc = 0.5101
# Epoch 7, step 20000/45000, batch loss = 1.36 batch_acc = 0.56, acc = 0.5018
# Epoch 7, step 22000/45000, batch loss = 1.47 batch_acc = 0.48, acc = 0.5024
# Epoch 7, step 24000/45000, batch loss = 1.43 batch_acc = 0.47, acc = 0.518
# Epoch 7, step 26000/45000, batch loss = 1.56 batch_acc = 0.42, acc = 0.5002
# Epoch 7, step 28000/45000, batch loss = 1.48 batch_acc = 0.52, acc = 0.5101
# Epoch 7, step 30000/45000, batch loss = 1.48 batch_acc = 0.53, acc = 0.4932
# Epoch 7, step 32000/45000, batch loss = 1.41 batch_acc = 0.55, acc = 0.5157
# Epoch 7, step 34000/45000, batch loss = 1.39 batch_acc = 0.49, acc = 0.4921
# Epoch 7, step 36000/45000, batch loss = 1.49 batch_acc = 0.46, acc = 0.4871
# Epoch 7, step 38000/45000, batch loss = 1.39 batch_acc = 0.58, acc = 0.4875
# Epoch 7, step 40000/45000, batch loss = 1.34 batch_acc = 0.53, acc = 0.4969
# Epoch 7, step 42000/45000, batch loss = 1.42 batch_acc = 0.5, acc = 0.52
# Epoch 7, step 44000/45000, batch loss = 1.37 batch_acc = 0.45, acc = 0.4847
# Epoch 8, step 0/45000, batch loss = 1.29 batch_acc = 0.53, acc = 0.4871
# Epoch 8, step 2000/45000, batch loss = 1.38 batch_acc = 0.57, acc = 0.5162
# Epoch 8, step 4000/45000, batch loss = 1.34 batch_acc = 0.51, acc = 0.4986
# Epoch 8, step 6000/45000, batch loss = 1.44 batch_acc = 0.5, acc = 0.5036
# Epoch 8, step 8000/45000, batch loss = 1.29 batch_acc = 0.5, acc = 0.513
# Epoch 8, step 10000/45000, batch loss = 1.28 batch_acc = 0.56, acc = 0.5053
# Epoch 8, step 12000/45000, batch loss = 1.23 batch_acc = 0.56, acc = 0.5205
# Epoch 8, step 14000/45000, batch loss = 1.46 batch_acc = 0.47, acc = 0.5232
# Epoch 8, step 16000/45000, batch loss = 1.39 batch_acc = 0.52, acc = 0.5227
# Epoch 8, step 18000/45000, batch loss = 1.33 batch_acc = 0.58, acc = 0.4962
# Epoch 8, step 20000/45000, batch loss = 1.21 batch_acc = 0.62, acc = 0.5156
# Epoch 8, step 22000/45000, batch loss = 1.43 batch_acc = 0.5, acc = 0.4898
# Epoch 8, step 24000/45000, batch loss = 1.38 batch_acc = 0.57, acc = 0.4939
# Epoch 8, step 26000/45000, batch loss = 1.23 batch_acc = 0.62, acc = 0.5125
# Epoch 8, step 28000/45000, batch loss = 1.21 batch_acc = 0.59, acc = 0.5211
# Epoch 8, step 30000/45000, batch loss = 1.43 batch_acc = 0.5, acc = 0.4839
# Epoch 8, step 32000/45000, batch loss = 1.42 batch_acc = 0.44, acc = 0.4944
# Epoch 8, step 34000/45000, batch loss = 1.49 batch_acc = 0.47, acc = 0.5085
# Epoch 8, step 36000/45000, batch loss = 1.35 batch_acc = 0.54, acc = 0.5004
# Epoch 8, step 38000/45000, batch loss = 1.40 batch_acc = 0.5, acc = 0.5245
# Epoch 8, step 40000/45000, batch loss = 1.34 batch_acc = 0.55, acc = 0.5246
# Epoch 8, step 42000/45000, batch loss = 1.56 batch_acc = 0.53, acc = 0.5051
# Epoch 8, step 44000/45000, batch loss = 1.45 batch_acc = 0.47, acc = 0.5326
# Testing Accuracy: 0.5147

# %% [markdown]
# # Restore model

# %%
sess = tf.Session()
sess.run(tf.initialize_all_variables())
saver = tf.train.Saver()
saver.restore(sess,'cifar.model-hinge.ckpt')

# %%
test_predict = sess.run(pred, feed_dict={x:test_x})
loss_test_predict = sess.run(cost,feed_dict={x:test_x, y: labels_to_one_hot(test_y,10)})

# %%
predict_klase = np.argmax(test_predict,axis=1)
indeksi_netocnih = np.where(predict_klase != test_y)
indeksi_netocnih = np.array(indeksi_netocnih).reshape(-1)
# loss_netocnih = [sess.run(cost,feed_dict={x:[test_x[i]],y:labels_to_one_hot(np.array([test_y[i]]),10)}) for i in indeksi_netocnih]

loss_netocnih = [sess.run(cost,feed_dict={x:[test_x[i]],y:labels_to_one_hot(np.array([test_y[i]]),10)}) for i,tmp in enumerate(test_y)]

# %%
sort_index = sorted(indeksi_netocnih, key = lambda x: loss_netocnih[x], reverse=True)

# %%
top_20_indices = sort_index[0:20]
for i,index in enumerate(top_20_indices):
    print "Loss for %dth top 20 worst examples is %.2f true class = %d, predicted = %d" % (i+1,loss_netocnih[index], test_y[index], np.argmax(test_predict[index]))
    draw_image(test_x[index],data_mean,data_std)
# Out:
# Loss for 1th top 20 worst examples is 3344.96 true class = 7, predicted = 6
# Loss for 2th top 20 worst examples is 2689.06 true class = 9, predicted = 7
# Loss for 3th top 20 worst examples is 2619.38 true class = 8, predicted = 6
# Loss for 4th top 20 worst examples is 2479.33 true class = 7, predicted = 3
# Loss for 5th top 20 worst examples is 2063.77 true class = 1, predicted = 4
# Loss for 6th top 20 worst examples is 2024.48 true class = 6, predicted = 0
# Loss for 7th top 20 worst examples is 1963.09 true class = 7, predicted = 8
# Loss for 8th top 20 worst examples is 1878.99 true class = 7, predicted = 6
# Loss for 9th top 20 worst examples is 1799.32 true class = 7, predicted = 6
# Loss for 10th top 20 worst examples is 1713.33 true class = 7, predicted = 8
# Loss for 11th top 20 worst examples is 1693.80 true class = 7, predicted = 3
# Loss for 12th top 20 worst examples is 1648.64 true class = 1, predicted = 3
# Loss for 13th top 20 worst examples is 1617.54 true class = 1, predicted = 3
# Loss for 14th top 20 worst examples is 1616.93 true class = 3, predicted = 4
# Loss for 15th top 20 worst examples is 1601.24 true class = 8, predicted = 2
# Loss for 16th top 20 worst examples is 1506.52 true class = 5, predicted = 9
# Loss for 17th top 20 worst examples is 1501.95 true class = 0, predicted = 5
# Loss for 18th top 20 worst examples is 1497.54 true class = 3, predicted = 2
# Loss for 19th top 20 worst examples is 1456.08 true class = 9, predicted = 3
# Loss for 20th top 20 worst examples is 1427.79 true class = 4, predicted = 7

# %% [markdown]
# # Testing sizes

# %%
size = 3
stride = 2
w = 32
h = 32
w = (1.*w-size)/stride +1
h = (1.*h-size)/stride +1 
print w,h
w = (1.*w-size)/stride +1
h = (1.*h-size)/stride +1
print w,h
# Out:
# 15.5 15.5
# 7.25 7.25

# %%
size = 3
stride = 2
w = 4
h = 4
w = ((w-1)*stride)+size
h = ((h-1)*stride)+size
print w,h
w = ((w-1)*stride)+size
h = ((h-1)*stride)+size
print w,h
