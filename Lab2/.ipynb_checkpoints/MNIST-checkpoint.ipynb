# %%
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/Users/mac/Documents/FER/DubokoUcenje/Lab1/MNIST_data", one_hot=True)
# Out:
# Extracting /Users/mac/Documents/FER/DubokoUcenje/Lab1/MNIST_data/train-images-idx3-ubyte.gz
# Extracting /Users/mac/Documents/FER/DubokoUcenje/Lab1/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /Users/mac/Documents/FER/DubokoUcenje/Lab1/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /Users/mac/Documents/FER/DubokoUcenje/Lab1/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
import os
import math
from copy import deepcopy
import numpy as np
import skimage as ski
import skimage.io

def draw_conv_filters(epoch, step, weights, save_dir, name):
    w = weights.copy()
    num_filters = w.shape[3]
    k = w.shape[0]
    #ovo dole treba biti C di je 1 al ono..
    w = w.reshape(num_filters, 1, w.shape[0], w.shape[0])
    w -= w.min()
    w /= 1.*w.max()
    border = 1
    cols = 8
    rows = math.ceil(num_filters / cols)
    width = cols * k + (cols-1) * border
    height = rows * k + (rows-1) * border
    for i in range(1):
        img = np.zeros([height, width])
        for j in range(16):
            r = int(j / cols) * (k + border)
            c = int(j % cols) * (k + border)
            img[r:r+k,c:c+k] = w[j,i]
    filename = '%s_epoch_%02d_step_%06d_input_%03d.png' % (name, epoch, step, i)
    ski.io.imsave(os.path.join(save_dir, filename), img)

# %%
# Parameters
learning_policy = {1:1e-1, 3:1e-2, 5:1e-3, 7:1e-4}
training_iters = 200000
batch_size = 50
max_epochs = 8
print_every_num_batches = 20
draw_filter = 100
wd = 1e-2
save_dir = './tensorflow_mnist'

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input

# %%
# Store layers weight & bias
weights = {
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 16])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 16, 32])),
    'wd1': tf.Variable(tf.random_normal([7*7*32, 512])),
    'out': tf.Variable(tf.random_normal([512, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([16])),
    'bc2': tf.Variable(tf.random_normal([32])),
    'bd1': tf.Variable(tf.random_normal([512])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases):#,dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    #fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Construct model
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
pred = conv_net(x, weights, biases)

# Define loss and optimizer
cost = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y) + tf.mul(tf.nn.l2_loss(weights['wc1']), wd)
                      + tf.mul(tf.nn.l2_loss(weights['wc2']), wd)
                      + tf.mul(tf.nn.l2_loss(weights['wd1']), wd)))


learning_rate = tf.placeholder(tf.float32, shape=[])
print learning_rate
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()
# Out:
# Tensor("Placeholder_28:0", shape=(), dtype=float32)

# %%
sess = tf.Session()
sess.run(init)
step = 1
for epoch in range(1, max_epochs):
    if epoch in learning_policy:
        lr = learning_policy[epoch]
        #sess.run([optimizer], feed_dict={learning_rate: 0.1})
    for i in range (mnist.train.num_examples/batch_size):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        _, loss = sess.run([optimizer,cost], feed_dict={x: batch_x, y: batch_y, learning_rate: 0.001})
        if i % print_every_num_batches ==0:
            print "Epoch %d, step %d/%d, batch loss = %.2f" % (epoch, i*batch_size, mnist.train.num_examples, loss)
        if i % draw_filter == 0:
            draw_conv_filters(epoch, i*batch_size, sess.run(weights['wc1']), save_dir, name = 'conv1')
            
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images,
                                  y: mnist.test.labels})
# Out:
# Epoch 1, step 0/55000, batch loss = 25992.89
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:22: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Epoch 1, step 1000/55000, batch loss = 9522.55
# Epoch 1, step 2000/55000, batch loss = 6990.71
# Epoch 1, step 3000/55000, batch loss = 5755.33
# Epoch 1, step 4000/55000, batch loss = 5850.57
# Epoch 1, step 5000/55000, batch loss = 5127.92
# Epoch 1, step 6000/55000, batch loss = 4928.12
# Epoch 1, step 7000/55000, batch loss = 5366.38
# Epoch 1, step 8000/55000, batch loss = 4238.44
# Epoch 1, step 9000/55000, batch loss = 5341.27
# Epoch 1, step 10000/55000, batch loss = 4674.63
# Epoch 1, step 11000/55000, batch loss = 4329.91
# Epoch 1, step 12000/55000, batch loss = 4075.67
# Epoch 1, step 13000/55000, batch loss = 4089.11
# Epoch 1, step 14000/55000, batch loss = 4306.04
# Epoch 1, step 15000/55000, batch loss = 4297.46
# Epoch 1, step 16000/55000, batch loss = 4235.80
# Epoch 1, step 17000/55000, batch loss = 4061.16
# Epoch 1, step 18000/55000, batch loss = 3903.27
# Epoch 1, step 19000/55000, batch loss = 3895.88
# Epoch 1, step 20000/55000, batch loss = 3847.60
# Epoch 1, step 21000/55000, batch loss = 3629.99
# Epoch 1, step 22000/55000, batch loss = 4029.34
# Epoch 1, step 23000/55000, batch loss = 3825.60
# Epoch 1, step 24000/55000, batch loss = 3875.05
# Epoch 1, step 25000/55000, batch loss = 3962.53
# Epoch 1, step 26000/55000, batch loss = 3804.26
# Epoch 1, step 27000/55000, batch loss = 3759.92
# Epoch 1, step 28000/55000, batch loss = 3458.78
# Epoch 1, step 29000/55000, batch loss = 3780.96
# Epoch 1, step 30000/55000, batch loss = 4032.67
# Epoch 1, step 31000/55000, batch loss = 3469.68
# Epoch 1, step 32000/55000, batch loss = 3741.25
# Epoch 1, step 33000/55000, batch loss = 3672.45
# Epoch 1, step 34000/55000, batch loss = 3432.44
# Epoch 1, step 35000/55000, batch loss = 3563.84
# Epoch 1, step 36000/55000, batch loss = 3936.12
# Epoch 1, step 37000/55000, batch loss = 3341.87
# Epoch 1, step 38000/55000, batch loss = 3521.87
# Epoch 1, step 39000/55000, batch loss = 3535.27
# Epoch 1, step 40000/55000, batch loss = 3721.69
# Epoch 1, step 41000/55000, batch loss = 3606.71
# Epoch 1, step 42000/55000, batch loss = 3411.18
# Epoch 1, step 43000/55000, batch loss = 3231.19
# Epoch 1, step 44000/55000, batch loss = 3429.72
# Epoch 1, step 45000/55000, batch loss = 3724.60
# Epoch 1, step 46000/55000, batch loss = 3271.00
# Epoch 1, step 47000/55000, batch loss = 3246.26
# Epoch 1, step 48000/55000, batch loss = 3446.52
# Epoch 1, step 49000/55000, batch loss = 3250.85
# Epoch 1, step 50000/55000, batch loss = 3239.72
# Epoch 1, step 51000/55000, batch loss = 3402.12
# Epoch 1, step 52000/55000, batch loss = 3364.96
# Epoch 1, step 53000/55000, batch loss = 3122.08
# Epoch 1, step 54000/55000, batch loss = 3226.12
# Epoch 2, step 0/55000, batch loss = 3168.19
# Epoch 2, step 1000/55000, batch loss = 3184.10
# Epoch 2, step 2000/55000, batch loss = 3365.58
# Epoch 2, step 3000/55000, batch loss = 3279.95
# Epoch 2, step 4000/55000, batch loss = 3598.10
# Epoch 2, step 5000/55000, batch loss = 3238.38
# Epoch 2, step 6000/55000, batch loss = 3087.44
# Epoch 2, step 7000/55000, batch loss = 3372.45
# Epoch 2, step 8000/55000, batch loss = 3204.35
# Epoch 2, step 9000/55000, batch loss = 3312.73
# Epoch 2, step 10000/55000, batch loss = 3103.01
# Epoch 2, step 11000/55000, batch loss = 3166.68
# Epoch 2, step 12000/55000, batch loss = 3024.43
# Epoch 2, step 13000/55000, batch loss = 3090.02
# Epoch 2, step 14000/55000, batch loss = 3476.05
# Epoch 2, step 15000/55000, batch loss = 3279.79
# Epoch 2, step 16000/55000, batch loss = 3021.59
# Epoch 2, step 17000/55000, batch loss = 3185.70
# Epoch 2, step 18000/55000, batch loss = 3011.04
# Epoch 2, step 19000/55000, batch loss = 2922.61
# Epoch 2, step 20000/55000, batch loss = 3030.90
# Epoch 2, step 21000/55000, batch loss = 3095.84
# Epoch 2, step 22000/55000, batch loss = 2935.09
# Epoch 2, step 23000/55000, batch loss = 2971.69
# Epoch 2, step 24000/55000, batch loss = 3108.54
# Epoch 2, step 25000/55000, batch loss = 2957.61
# Epoch 2, step 26000/55000, batch loss = 3154.13
# Epoch 2, step 27000/55000, batch loss = 3123.05
# Epoch 2, step 28000/55000, batch loss = 2886.64
# Epoch 2, step 29000/55000, batch loss = 3109.76
# Epoch 2, step 30000/55000, batch loss = 2837.74
# Epoch 2, step 31000/55000, batch loss = 2853.32
# Epoch 2, step 32000/55000, batch loss = 3103.21
# Epoch 2, step 33000/55000, batch loss = 2828.83
# Epoch 2, step 34000/55000, batch loss = 2812.43
# Epoch 2, step 35000/55000, batch loss = 2990.78
# Epoch 2, step 36000/55000, batch loss = 3180.30
# Epoch 2, step 37000/55000, batch loss = 2858.80
# Epoch 2, step 38000/55000, batch loss = 2856.13
# Epoch 2, step 39000/55000, batch loss = 2984.85
# Epoch 2, step 40000/55000, batch loss = 2774.30
# Epoch 2, step 41000/55000, batch loss = 2900.09
# Epoch 2, step 42000/55000, batch loss = 3121.91
# Epoch 2, step 43000/55000, batch loss = 2937.13
# Epoch 2, step 44000/55000, batch loss = 2904.13
# Epoch 2, step 45000/55000, batch loss = 3126.86
# Epoch 2, step 46000/55000, batch loss = 2938.96
# Epoch 2, step 47000/55000, batch loss = 2853.36
# Epoch 2, step 48000/55000, batch loss = 2882.68
# Epoch 2, step 49000/55000, batch loss = 2823.52
# Epoch 2, step 50000/55000, batch loss = 3016.07
# Epoch 2, step 51000/55000, batch loss = 2900.72
# Epoch 2, step 52000/55000, batch loss = 2738.20
# Epoch 2, step 53000/55000, batch loss = 2704.63
# Epoch 2, step 54000/55000, batch loss = 2693.05
# Epoch 3, step 0/55000, batch loss = 2755.57
# Epoch 3, step 1000/55000, batch loss = 2862.80
# Epoch 3, step 2000/55000, batch loss = 3171.26
# Epoch 3, step 3000/55000, batch loss = 2798.66
# Epoch 3, step 4000/55000, batch loss = 2699.24
# Epoch 3, step 5000/55000, batch loss = 2787.07
# Epoch 3, step 6000/55000, batch loss = 2690.19
# Epoch 3, step 7000/55000, batch loss = 2717.92
# Epoch 3, step 8000/55000, batch loss = 2662.29
# Epoch 3, step 9000/55000, batch loss = 2702.40
# Epoch 3, step 10000/55000, batch loss = 2659.96
# Epoch 3, step 11000/55000, batch loss = 2813.33
# Epoch 3, step 12000/55000, batch loss = 2701.65
# Epoch 3, step 13000/55000, batch loss = 2595.89
# Epoch 3, step 14000/55000, batch loss = 2586.63
# Epoch 3, step 15000/55000, batch loss = 2588.56
# Epoch 3, step 16000/55000, batch loss = 2697.55
# Epoch 3, step 17000/55000, batch loss = 2597.13
# Epoch 3, step 18000/55000, batch loss = 2574.50
# Epoch 3, step 19000/55000, batch loss = 2723.42
# Epoch 3, step 20000/55000, batch loss = 2561.66
# Epoch 3, step 21000/55000, batch loss = 2560.86
# Epoch 3, step 22000/55000, batch loss = 2591.91
# Epoch 3, step 23000/55000, batch loss = 2643.15
# Epoch 3, step 24000/55000, batch loss = 2559.25
# Epoch 3, step 25000/55000, batch loss = 2650.53
# Epoch 3, step 26000/55000, batch loss = 2647.13
# Epoch 3, step 27000/55000, batch loss = 2512.02
# Epoch 3, step 28000/55000, batch loss = 2539.96
# Epoch 3, step 29000/55000, batch loss = 2742.09
# Epoch 3, step 30000/55000, batch loss = 2506.71
# Epoch 3, step 31000/55000, batch loss = 2519.59
# Epoch 3, step 32000/55000, batch loss = 2541.88
# Epoch 3, step 33000/55000, batch loss = 2495.78
# Epoch 3, step 34000/55000, batch loss = 2648.18
# Epoch 3, step 35000/55000, batch loss = 2634.58
# Epoch 3, step 36000/55000, batch loss = 2564.31
# Epoch 3, step 37000/55000, batch loss = 2465.96
# Epoch 3, step 38000/55000, batch loss = 2640.98
# Epoch 3, step 39000/55000, batch loss = 2600.80
# Epoch 3, step 40000/55000, batch loss = 2440.06
# Epoch 3, step 41000/55000, batch loss = 2624.00
# Epoch 3, step 42000/55000, batch loss = 2648.65
# Epoch 3, step 43000/55000, batch loss = 2515.00
# Epoch 3, step 44000/55000, batch loss = 2679.83
# Epoch 3, step 45000/55000, batch loss = 2415.99
# Epoch 3, step 46000/55000, batch loss = 2613.84
# Epoch 3, step 47000/55000, batch loss = 2507.88
# Epoch 3, step 48000/55000, batch loss = 2616.37
# Epoch 3, step 49000/55000, batch loss = 2813.84
# Epoch 3, step 50000/55000, batch loss = 2459.73
# Epoch 3, step 51000/55000, batch loss = 2470.58
# Epoch 3, step 52000/55000, batch loss = 2421.56
# Epoch 3, step 53000/55000, batch loss = 2416.08
# Epoch 3, step 54000/55000, batch loss = 2365.37
# Epoch 4, step 0/55000, batch loss = 2360.09
# Epoch 4, step 1000/55000, batch loss = 2371.15
# Epoch 4, step 2000/55000, batch loss = 2349.55
# Epoch 4, step 3000/55000, batch loss = 2346.34
# Epoch 4, step 4000/55000, batch loss = 2362.40
# Epoch 4, step 5000/55000, batch loss = 2363.70
# Epoch 4, step 6000/55000, batch loss = 2400.91
# Epoch 4, step 7000/55000, batch loss = 2343.64
# Epoch 4, step 8000/55000, batch loss = 2348.88
# Epoch 4, step 9000/55000, batch loss = 2312.89
# Epoch 4, step 10000/55000, batch loss = 2465.77
# Epoch 4, step 11000/55000, batch loss = 2302.52
# Epoch 4, step 12000/55000, batch loss = 2297.33
# Epoch 4, step 13000/55000, batch loss = 2333.62
# Epoch 4, step 14000/55000, batch loss = 2384.36
# Epoch 4, step 15000/55000, batch loss = 2281.74
# Epoch 4, step 16000/55000, batch loss = 2427.08
# Epoch 4, step 17000/55000, batch loss = 2271.37
# Epoch 4, step 18000/55000, batch loss = 2277.68
# Epoch 4, step 19000/55000, batch loss = 2260.98
# Epoch 4, step 20000/55000, batch loss = 2255.85
# Epoch 4, step 21000/55000, batch loss = 2287.04
# Epoch 4, step 22000/55000, batch loss = 2299.67
# Epoch 4, step 23000/55000, batch loss = 2240.49
# Epoch 4, step 24000/55000, batch loss = 2301.91
# Epoch 4, step 25000/55000, batch loss = 2230.27
# Epoch 4, step 26000/55000, batch loss = 2234.25
# Epoch 4, step 27000/55000, batch loss = 2241.22
# Epoch 4, step 28000/55000, batch loss = 2242.64
# Epoch 4, step 29000/55000, batch loss = 2332.79
# Epoch 4, step 30000/55000, batch loss = 2228.35
# Epoch 4, step 31000/55000, batch loss = 2338.69
# Epoch 4, step 32000/55000, batch loss = 2198.87
# Epoch 4, step 33000/55000, batch loss = 2229.13
# Epoch 4, step 34000/55000, batch loss = 2207.15
# Epoch 4, step 35000/55000, batch loss = 2184.21
# Epoch 4, step 36000/55000, batch loss = 2174.58
# Epoch 4, step 37000/55000, batch loss = 2215.10
# Epoch 4, step 38000/55000, batch loss = 2208.69
# Epoch 4, step 39000/55000, batch loss = 2220.58
# Epoch 4, step 40000/55000, batch loss = 2171.23
# Epoch 4, step 41000/55000, batch loss = 2302.28
# Epoch 4, step 42000/55000, batch loss = 2203.49
# Epoch 4, step 43000/55000, batch loss = 2139.56
# Epoch 4, step 44000/55000, batch loss = 2287.45
# Epoch 4, step 45000/55000, batch loss = 2163.62
# Epoch 4, step 46000/55000, batch loss = 2201.66
# Epoch 4, step 47000/55000, batch loss = 2124.35
# Epoch 4, step 48000/55000, batch loss = 2173.10
# Epoch 4, step 49000/55000, batch loss = 2182.48
# Epoch 4, step 50000/55000, batch loss = 2104.67
# Epoch 4, step 51000/55000, batch loss = 2099.73
# Epoch 4, step 52000/55000, batch loss = 2094.76
# Epoch 4, step 53000/55000, batch loss = 2101.74
# Epoch 4, step 54000/55000, batch loss = 2084.84
# Epoch 5, step 0/55000, batch loss = 2155.56
# Epoch 5, step 1000/55000, batch loss = 2074.91
# Epoch 5, step 2000/55000, batch loss = 2236.40
# Epoch 5, step 3000/55000, batch loss = 2131.69
# Epoch 5, step 4000/55000, batch loss = 2060.08
# Epoch 5, step 5000/55000, batch loss = 2072.82
# Epoch 5, step 6000/55000, batch loss = 2095.21
# Epoch 5, step 7000/55000, batch loss = 2165.61
# Epoch 5, step 8000/55000, batch loss = 2040.35
# Epoch 5, step 9000/55000, batch loss = 2037.30
# Epoch 5, step 10000/55000, batch loss = 2086.69
# Epoch 5, step 11000/55000, batch loss = 2048.71
# Epoch 5, step 12000/55000, batch loss = 2020.67
# Epoch 5, step 13000/55000, batch loss = 2069.40
# Epoch 5, step 14000/55000, batch loss = 2016.66
# Epoch 5, step 15000/55000, batch loss = 2046.52
# Epoch 5, step 16000/55000, batch loss = 2039.52
# Epoch 5, step 17000/55000, batch loss = 2093.06
# Epoch 5, step 18000/55000, batch loss = 1998.34
# Epoch 5, step 19000/55000, batch loss = 2074.67
# Epoch 5, step 20000/55000, batch loss = 1987.42
# Epoch 5, step 21000/55000, batch loss = 1987.24
# Epoch 5, step 22000/55000, batch loss = 2022.09
# Epoch 5, step 23000/55000, batch loss = 1967.15
# Epoch 5, step 24000/55000, batch loss = 1962.32
# Epoch 5, step 25000/55000, batch loss = 2175.80
# Epoch 5, step 26000/55000, batch loss = 1952.75
# Epoch 5, step 27000/55000, batch loss = 1960.14
# Epoch 5, step 28000/55000, batch loss = 2017.21
# Epoch 5, step 29000/55000, batch loss = 1955.55
# Epoch 5, step 30000/55000, batch loss = 2058.61
# Epoch 5, step 31000/55000, batch loss = 1928.85
# Epoch 5, step 32000/55000, batch loss = 1979.23
# Epoch 5, step 33000/55000, batch loss = 1961.52
# Epoch 5, step 34000/55000, batch loss = 1914.61
# Epoch 5, step 35000/55000, batch loss = 1966.51
# Epoch 5, step 36000/55000, batch loss = 1942.98
# Epoch 5, step 37000/55000, batch loss = 1908.56
# Epoch 5, step 38000/55000, batch loss = 1896.46
# Epoch 5, step 39000/55000, batch loss = 1916.49
# Epoch 5, step 40000/55000, batch loss = 1966.06
# Epoch 5, step 41000/55000, batch loss = 1939.76
# Epoch 5, step 42000/55000, batch loss = 1879.15
# Epoch 5, step 43000/55000, batch loss = 1893.98
# Epoch 5, step 44000/55000, batch loss = 1867.96
# Epoch 5, step 45000/55000, batch loss = 1891.42
# Epoch 5, step 46000/55000, batch loss = 1858.70
# Epoch 5, step 47000/55000, batch loss = 1854.06
# Epoch 5, step 48000/55000, batch loss = 1849.41
# Epoch 5, step 49000/55000, batch loss = 1845.50
# Epoch 5, step 50000/55000, batch loss = 1862.46
# Epoch 5, step 51000/55000, batch loss = 1858.47
# Epoch 5, step 52000/55000, batch loss = 1830.92
# Epoch 5, step 53000/55000, batch loss = 1863.42
# Epoch 5, step 54000/55000, batch loss = 1839.37
# Epoch 6, step 0/55000, batch loss = 1817.00
# Epoch 6, step 1000/55000, batch loss = 1876.83
# Epoch 6, step 2000/55000, batch loss = 1840.45
# Epoch 6, step 3000/55000, batch loss = 1818.04
# Epoch 6, step 4000/55000, batch loss = 1798.51
# Epoch 6, step 5000/55000, batch loss = 1793.89
# Epoch 6, step 6000/55000, batch loss = 1789.25
# Epoch 6, step 7000/55000, batch loss = 1814.33
# Epoch 6, step 8000/55000, batch loss = 1779.98
# Epoch 6, step 9000/55000, batch loss = 1788.64
# Epoch 6, step 10000/55000, batch loss = 1770.66
# Epoch 6, step 11000/55000, batch loss = 1829.90
# Epoch 6, step 12000/55000, batch loss = 1761.38
# Epoch 6, step 13000/55000, batch loss = 1785.13
# Epoch 6, step 14000/55000, batch loss = 1752.20
# Epoch 6, step 15000/55000, batch loss = 1747.65
# Epoch 6, step 16000/55000, batch loss = 1768.48
# Epoch 6, step 17000/55000, batch loss = 1738.47
# Epoch 6, step 18000/55000, batch loss = 1799.03
# Epoch 6, step 19000/55000, batch loss = 1729.32
# Epoch 6, step 20000/55000, batch loss = 1724.77
# Epoch 6, step 21000/55000, batch loss = 1747.24
# Epoch 6, step 22000/55000, batch loss = 1738.73
# Epoch 6, step 23000/55000, batch loss = 1727.20
# Epoch 6, step 24000/55000, batch loss = 1708.53
# Epoch 6, step 25000/55000, batch loss = 1730.87
# Epoch 6, step 26000/55000, batch loss = 1697.57
# Epoch 6, step 27000/55000, batch loss = 1723.94
# Epoch 6, step 28000/55000, batch loss = 1760.68
# Epoch 6, step 29000/55000, batch loss = 1719.61
# Epoch 6, step 30000/55000, batch loss = 1702.94
# Epoch 6, step 31000/55000, batch loss = 1738.65
# Epoch 6, step 32000/55000, batch loss = 1722.40
# Epoch 6, step 33000/55000, batch loss = 1672.50
# Epoch 6, step 34000/55000, batch loss = 1675.66
# Epoch 6, step 35000/55000, batch loss = 1770.58
# Epoch 6, step 36000/55000, batch loss = 1694.66
# Epoch 6, step 37000/55000, batch loss = 1651.51
# Epoch 6, step 38000/55000, batch loss = 1727.81
# Epoch 6, step 39000/55000, batch loss = 1658.25
# Epoch 6, step 40000/55000, batch loss = 1693.05
# Epoch 6, step 41000/55000, batch loss = 1669.87
# Epoch 6, step 42000/55000, batch loss = 1637.31
# Epoch 6, step 43000/55000, batch loss = 1621.88
# Epoch 6, step 44000/55000, batch loss = 1638.16
# Epoch 6, step 45000/55000, batch loss = 1613.18
# Epoch 6, step 46000/55000, batch loss = 1608.84
# Epoch 6, step 47000/55000, batch loss = 1604.48
# Epoch 6, step 48000/55000, batch loss = 1615.52
# Epoch 6, step 49000/55000, batch loss = 1642.71
# Epoch 6, step 50000/55000, batch loss = 1591.45
# Epoch 6, step 51000/55000, batch loss = 1598.05
# Epoch 6, step 52000/55000, batch loss = 1616.12
# Epoch 6, step 53000/55000, batch loss = 1602.14
# Epoch 6, step 54000/55000, batch loss = 1574.10
# Epoch 7, step 0/55000, batch loss = 1569.76
# Epoch 7, step 1000/55000, batch loss = 1565.39
# Epoch 7, step 2000/55000, batch loss = 1565.80
# Epoch 7, step 3000/55000, batch loss = 1589.92
# Epoch 7, step 4000/55000, batch loss = 1555.06
# Epoch 7, step 5000/55000, batch loss = 1557.21
# Epoch 7, step 6000/55000, batch loss = 1555.49
# Epoch 7, step 7000/55000, batch loss = 1539.49
# Epoch 7, step 8000/55000, batch loss = 1535.16
# Epoch 7, step 9000/55000, batch loss = 1530.83
# Epoch 7, step 10000/55000, batch loss = 1543.59
# Epoch 7, step 11000/55000, batch loss = 1522.27
# Epoch 7, step 12000/55000, batch loss = 1549.84
# Epoch 7, step 13000/55000, batch loss = 1539.62
# Epoch 7, step 14000/55000, batch loss = 1511.49
# Epoch 7, step 15000/55000, batch loss = 1547.72
# Epoch 7, step 16000/55000, batch loss = 1524.89
# Epoch 7, step 17000/55000, batch loss = 1504.85
# Epoch 7, step 18000/55000, batch loss = 1510.19
# Epoch 7, step 19000/55000, batch loss = 1547.79
# Epoch 7, step 20000/55000, batch loss = 1483.98
# Epoch 7, step 21000/55000, batch loss = 1479.74
# Epoch 7, step 22000/55000, batch loss = 1496.67
# Epoch 7, step 23000/55000, batch loss = 1496.18
# Epoch 7, step 24000/55000, batch loss = 1578.35
# Epoch 7, step 25000/55000, batch loss = 1500.08
# Epoch 7, step 26000/55000, batch loss = 1470.10
# Epoch 7, step 27000/55000, batch loss = 1466.26
# Epoch 7, step 28000/55000, batch loss = 1480.09
# Epoch 7, step 29000/55000, batch loss = 1447.17
# Epoch 7, step 30000/55000, batch loss = 1460.05
# Epoch 7, step 31000/55000, batch loss = 1437.64
# Epoch 7, step 32000/55000, batch loss = 1433.46
# Epoch 7, step 33000/55000, batch loss = 1429.29
# Epoch 7, step 34000/55000, batch loss = 1468.93
# Epoch 7, step 35000/55000, batch loss = 1474.02
# Epoch 7, step 36000/55000, batch loss = 1416.92
# Epoch 7, step 37000/55000, batch loss = 1431.92
# Epoch 7, step 38000/55000, batch loss = 1429.54
# Epoch 7, step 39000/55000, batch loss = 1485.23
# Epoch 7, step 40000/55000, batch loss = 1403.24
# Epoch 7, step 41000/55000, batch loss = 1396.55
# Epoch 7, step 42000/55000, batch loss = 1425.22
# Epoch 7, step 43000/55000, batch loss = 1503.67
# Epoch 7, step 44000/55000, batch loss = 1394.41
# Epoch 7, step 45000/55000, batch loss = 1391.71
# Epoch 7, step 46000/55000, batch loss = 1380.58
# Epoch 7, step 47000/55000, batch loss = 1376.71
# Epoch 7, step 48000/55000, batch loss = 1395.72
# Epoch 7, step 49000/55000, batch loss = 1364.58
# Epoch 7, step 50000/55000, batch loss = 1378.37
# Epoch 7, step 51000/55000, batch loss = 1368.30
# Epoch 7, step 52000/55000, batch loss = 1352.66
# Epoch 7, step 53000/55000, batch loss = 1348.68
# Epoch 7, step 54000/55000, batch loss = 1344.68
# Testing Accuracy: 0.9743

# %%
import matplotlib.pyplot as plt

def visualize_grid(Xs, ubound=255.0, padding=1):
    (N, H, W, C) = Xs.shape
    print Xs.shape
    grid_size = int(math.ceil(np.sqrt(N)))
    grid_height = H * grid_size + padding * (grid_size - 1)
    grid_width = W * grid_size + padding * (grid_size - 1)
    grid = np.zeros((grid_height, grid_width, C))
    next_idx = 0
    y0, y1 = 0, H
    for y in xrange(grid_size):
        x0, x1 = 0, W
        for x in xrange(grid_size):
            if next_idx < N:
                img = Xs[next_idx]
                low, high = np.min(img), np.max(img)
                grid[y0:y1, x0:x1] = ubound * (img - low) / (high - low)
                # grid[y0:y1, x0:x1] = Xs[next_idx]
                next_idx += 1
            x0 += W + padding
            x1 += W + padding
        y0 += H + padding
        y1 += H + padding
    return grid

grid = visualize_grid(np.array(sess.run(weights['wc1']).transpose(3, 1, 0, 2)))
print grid.astype('uint8').shape
plt.figure(figsize=(16,8))
plt.imshow(grid.astype('uint8')[:,:,0],cmap='hot')
plt.show()
# Out:
# (16, 5, 5, 1)
# (23, 23, 1)
